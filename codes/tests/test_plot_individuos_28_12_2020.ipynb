# %%
import numpy as np
import random
import sys
import matplotlib.pyplot as plt
import pandas as pd
a = sys.path.append('../modules/') # endereco das funcoes implementadas por voce!
import plot_3D, auxiliars, salve_doc, sphere, sample_random, Operators
import test_operators_28_12_2020 as top
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection
# Out:
# geracao 0
# 17.093468278615642
# geracao 1
# 17.093468278615642
# geracao 2
# 16.427776791497486
# geracao 3
# 16.321955005932182
# geracao 4
# 16.14351414773009
# geracao 5
# 16.14351414773009
# geracao 6
# 16.14351414773009
# geracao 7
# 16.14351414773009
# geracao 8
# 16.050682806248563
# geracao 9
# 16.050682806248563
# geracao 10
# 16.050682806248563
# geracao 11
# 16.050682806248563
# geracao 12
# 16.050682806248563
# geracao 13
# 16.050682806248563
# geracao 14
# 16.050682806248563
# geracao 15
# 16.050682806248563
# geracao 16
# 16.050682806248563
# geracao 17
# 16.05047324567426
# geracao 18
# 16.05047324567426
# geracao 19
# 16.05047324567426
# geracao 20
# 16.05047324567426
# geracao 21
# 16.05047324567426
# geracao 22
# 16.05047324567426
# geracao 23
# 16.05047324567426
# geracao 24
# 16.05047324567426
# geracao 25
# 16.05047324567426
# geracao 26
# 16.05047324567426
# geracao 27
# 16.05047324567426
# geracao 28
# 16.05047324567426
# geracao 29
# 16.05047324567426
# ...

# %%
fit_rodada = top.val_fit
#theta_rodada = top.val_theta

# %%
n_fit = len(fit_rodada)
#print(n_fit)
#print(theta_rodada)

# %%
x = np.linspace(0, n_fit, n_fit)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, fit_rodada)
plt.ylim(0, max(fit_rodada))
plt.xlabel('Número de Gerações', fontsize=20)
plt.ylabel('fitness', fontsize=20)
plt.grid()
plt.show()

# %%
'''x = np.linspace(0, n_fit, n_fit)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, theta_rodada)
plt.ylim(0, max(theta_rodada))
plt.xlabel('Número de Gerações', fontsize=20)
plt.ylabel('theta', fontsize=20)
plt.grid()
plt.show()'''
