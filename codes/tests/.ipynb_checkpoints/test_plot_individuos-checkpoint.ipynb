# %%
import numpy as np
import random
import sys
import matplotlib.pyplot as plt
import pandas as pd
a = sys.path.append('../modules/') # endereco das funcoes implementadas por voce!
import plot_3D, auxiliars, salve_doc, sphere, sample_random, Operators
import test_operators_27_11_2020 as top
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection
# Out:
# 20
# 20
# geracao 0
# Fitness= 17.80432731727854
# 20
# 20
# geracao 1
# Fitness= 17.80432731727854
# 20
# 20
# geracao 2
# Fitness= 17.80432731727854
# 20
# 20
# geracao 3
# Fitness= 17.003973732167093
# 20
# 20
# geracao 4
# Fitness= 17.003973732167093
# 20
# 20
# geracao 5
# Fitness= 17.003973732167093
# 20
# 20
# geracao 6
# Fitness= 17.003973732167093
# 20
# 20
# geracao 7
# Fitness= 17.003973732167093
# 20
# 20
# geracao 8
# Fitness= 16.814391406609236
# 20
# 20
# geracao 9
# Fitness= 16.814391406609236
# 20
# 20
# geracao 10
# Fitness= 16.814391406609236
# 20
# 20
# geracao 11
# Fitness= 16.77632903012064
# 20
# 20
# geracao 12
# Fitness= 16.710800588108288
# 20
# 20
# geracao 13
# Fitness= 16.710800588108288
# 20
# 20
# geracao 14
# Fitness= 16.061353967793202
# 20
# 20
# geracao 15
# Fitness= 15.93283435058602
# 20
# 20
# geracao 16
# Fitness= 15.93283435058602
# 20
# 20
# geracao 17
# Fitness= 15.081095510644797
# 20
# 20
# geracao 18
# Fitness= 15.081095510644797
# 20
# 20
# geracao 19
# Fitness= 15.053551889187574
# 20
# 20
# geracao 20
# Fitness= 14.164127088220619
# 20
# 20
# geracao 21
# Fitness= 13.737466376964685
# 20
# 20
# geracao 22
# Fitness= 13.737466376964685
# 20
# 20
# geracao 23
# Fitness= 13.737466376964685
# 20
# 20
# geracao 24
# Fitness= 13.737466376964685
# 20
# 20
# geracao 25
# Fitness= 13.737466376964685
# 20
# 20
# geracao 26
# Fitness= 13.22083821334395
# 20
# 20
# geracao 27
# Fitness= 13.22083821334395
# 20
# 20
# geracao 28
# Fitness= 13.22083821334395
# 20
# 20
# geracao 29
# Fitness= 13.22083821334395
# 20
# 20
# geracao 30
# Fitness= 13.22083821334395
# 20
# 20
# geracao 31
# Fitness= 13.22083821334395
# 20
# 20
# geracao 32
# Fitness= 13.22083821334395
# 20
# 20
# geracao 33
# Fitness= 12.697751419414434
# 20
# 20
# geracao 34
# Fitness= 12.604344502239126
# 20
# 20
# geracao 35
# Fitness= 12.604344502239126
# 20
# 20
# geracao 36
# Fitness= 12.448894434761327
# 20
# 20
# geracao 37
# Fitness= 12.248463310409686
# 20
# 20
# geracao 38
# Fitness= 12.248463310409686
# 20
# 20
# geracao 39
# Fitness= 12.248463310409686
# 20
# 20
# geracao 40
# Fitness= 12.248463310409686
# 20
# 20
# geracao 41
# Fitness= 12.248463310409686
# 20
# 20
# geracao 42
# Fitness= 12.248463310409686
# 20
# 20
# geracao 43
# Fitness= 12.05021858255834
# 20
# 20
# geracao 44
# Fitness= 12.05021858255834
# 20
# 20
# geracao 45
# Fitness= 12.05021858255834
# 20
# 20
# geracao 46
# Fitness= 11.94915035977609
# 20
# 20
# geracao 47
# Fitness= 11.94915035977609
# 20
# 20
# geracao 48
# Fitness= 11.94915035977609
# 20
# 20
# geracao 49
# Fitness= 11.94915035977609
# 20
# 20
# geracao 50
# Fitness= 11.928744450833545
# 20
# 20
# geracao 51
# Fitness= 11.928744450833545
# 20
# 20
# geracao 52
# Fitness= 11.928744450833545
# 20
# 20
# geracao 53
# Fitness= 11.788178100890052
# 20
# 20
# geracao 54
# Fitness= 11.509283463708865
# 20
# 20
# geracao 55
# Fitness= 11.509283463708865
# 20
# 20
# geracao 56
# Fitness= 11.3915369004449
# 20
# 20
# geracao 57
# Fitness= 11.3915369004449
# 20
# 20
# geracao 58
# Fitness= 11.3915369004449
# 20
# 20
# geracao 59
# Fitness= 11.278831329568265
# 20
# 20
# geracao 60
# Fitness= 11.163335723995376
# 20
# 20
# geracao 61
# Fitness= 11.163335723995376
# 20
# 20
# geracao 62
# Fitness= 11.095320086497349
# 20
# 20
# geracao 63
# Fitness= 11.095320086497349
# 20
# 20
# geracao 64
# Fitness= 10.968013162230008
# 20
# 20
# geracao 65
# Fitness= 10.968013162230008
# 20
# 20
# geracao 66
# Fitness= 10.968013162230008
# 20
# 20
# geracao 67
# Fitness= 10.968013162230008
# 20
# 20
# geracao 68
# Fitness= 10.968013162230008
# 20
# 20
# geracao 69
# Fitness= 10.968013162230008
# 20
# 20
# geracao 70
# Fitness= 10.968013162230008
# 20
# 20
# geracao 71
# Fitness= 10.968013162230008
# 20
# 20
# geracao 72
# Fitness= 10.965445813325422
# 20
# 20
# geracao 73
# Fitness= 10.965445813325422
# 20
# 20
# geracao 74
# Fitness= 10.965445813325422
# 20
# 20
# geracao 75
# Fitness= 10.965445813325422
# 20
# 20
# geracao 76
# Fitness= 10.963606160861314
# 20
# 20
# geracao 77
# Fitness= 10.963606160861314
# 20
# 20
# geracao 78
# Fitness= 10.963606160861314
# 20
# 20
# geracao 79
# Fitness= 10.963606160861314
# 20
# 20
# geracao 80
# Fitness= 10.963606160861314
# 20
# 20
# geracao 81
# Fitness= 10.963606160861314
# 20
# 20
# geracao 82
# Fitness= 10.342310149892878
# 20
# 20
# geracao 83
# Fitness= 10.342310149892878
# 20
# 20
# geracao 84
# Fitness= 10.340857635714759
# 20
# 20
# geracao 85
# Fitness= 10.340857635714759
# 20
# 20
# geracao 86
# Fitness= 10.340857635714759
# 20
# 20
# geracao 87
# Fitness= 10.340857635714759
# 20
# 20
# geracao 88
# Fitness= 10.340857635714759
# 20
# 20
# geracao 89
# Fitness= 10.340857635714759
# 20
# 20
# geracao 90
# Fitness= 10.340857635714759
# 20
# 20
# geracao 91
# Fitness= 10.340857635714759
# 20
# 20
# geracao 92
# Fitness= 10.340857635714759
# 20
# 20
# geracao 93
# Fitness= 10.340857635714759
# 20
# 20
# geracao 94
# Fitness= 10.340857635714759
# 20
# 20
# geracao 95
# Fitness= 10.340857635714759
# 20
# 20
# geracao 96
# Fitness= 10.340857635714759
# 20
# 20
# geracao 97
# Fitness= 10.340857635714759
# 20
# 20
# geracao 98
# Fitness= 10.340857635714759
# 20
# 20
# geracao 99
# Fitness= 10.340857635714759
# 20
# 20
# geracao 100
# Fitness= 10.340857635714759
# 20
# 20
# geracao 101
# Fitness= 10.340857635714759
# 20
# 20
# geracao 102
# Fitness= 10.283991679070791
# 20
# 20
# geracao 103
# Fitness= 10.283991679070791
# 20
# 20
# geracao 104
# Fitness= 10.283991679070791
# 20
# 20
# geracao 105
# Fitness= 10.16266233378721
# 20
# 20
# geracao 106
# Fitness= 10.16266233378721
# 20
# 20
# geracao 107
# Fitness= 10.16266233378721
# 20
# 20
# geracao 108
# Fitness= 10.16266233378721
# 20
# 20
# geracao 109
# Fitness= 10.16266233378721
# 20
# 20
# geracao 110
# Fitness= 10.16266233378721
# 20
# 20
# geracao 111
# Fitness= 10.16266233378721
# 20
# 20
# geracao 112
# Fitness= 10.16266233378721
# 20
# 20
# geracao 113
# Fitness= 10.16266233378721
# 20
# 20
# geracao 114
# Fitness= 10.162345457512165
# 20
# 20
# geracao 115
# Fitness= 10.058097090666674
# 20
# 20
# geracao 116
# Fitness= 10.058097090666674
# 20
# 20
# geracao 117
# Fitness= 10.058097090666674
# 20
# 20
# geracao 118
# Fitness= 10.058097090666674
# 20
# 20
# geracao 119
# Fitness= 10.057786176245834
# 20
# 20
# geracao 120
# Fitness= 10.057786176245834
# 20
# 20
# geracao 121
# Fitness= 10.057786176245834
# 20
# 20
# geracao 122
# Fitness= 10.046871440285564
# 20
# 20
# geracao 123
# Fitness= 10.046871440285564
# 20
# 20
# geracao 124
# Fitness= 10.0465638252461
# 20
# 20
# geracao 125
# Fitness= 10.0465638252461
# 20
# 20
# geracao 126
# Fitness= 10.0465638252461
# 20
# 20
# geracao 127
# Fitness= 10.0465638252461
# 20
# 20
# geracao 128
# Fitness= 10.041377442309653
# 20
# 20
# geracao 129
# Fitness= 10.041377442309653
# 20
# 20
# geracao 130
# Fitness= 10.041377442309653
# 20
# 20
# geracao 131
# Fitness= 10.041377442309653
# 20
# 20
# geracao 132
# Fitness= 10.041377442309653
# 20
# 20
# geracao 133
# Fitness= 10.041377442309653
# 20
# 20
# geracao 134
# Fitness= 10.041377442309653
# 20
# 20
# geracao 135
# Fitness= 10.041377442309653
# 20
# 20
# geracao 136
# Fitness= 10.041377442309653
# 20
# 20
# geracao 137
# Fitness= 10.041377442309653
# 20
# 20
# geracao 138
# Fitness= 10.041377442309653
# 20
# 20
# geracao 139
# Fitness= 9.849979904582517
# 20
# 20
# geracao 140
# Fitness= 9.849979904582517
# 20
# 20
# geracao 141
# Fitness= 9.849979904582517
# 20
# 20
# geracao 142
# Fitness= 9.849979904582517
# 20
# 20
# geracao 143
# Fitness= 9.848698068050794
# 20
# 20
# geracao 144
# Fitness= 9.8485436437255
# 20
# 20
# geracao 145
# Fitness= 9.847245102890835
# 20
# 20
# geracao 146
# Fitness= 9.847245102890835
# 20
# 20
# geracao 147
# Fitness= 9.847245102890835
# 20
# 20
# geracao 148
# Fitness= 9.847245102890835
# 20
# 20
# geracao 149
# Fitness= 9.847245102890835
# 20
# 20
# geracao 150
# Fitness= 9.847245102890835
# 20
# 20
# geracao 151
# Fitness= 9.82469675718843
# 20
# 20
# geracao 152
# Fitness= 9.82469675718843
# 20
# 20
# geracao 153
# Fitness= 9.82469675718843
# 20
# 20
# geracao 154
# Fitness= 9.82469675718843
# 20
# 20
# geracao 155
# Fitness= 9.82469675718843
# 20
# 20
# geracao 156
# Fitness= 9.82469675718843
# 20
# 20
# geracao 157
# Fitness= 9.823355322615509
# 20
# 20
# geracao 158
# Fitness= 9.823355322615509
# 20
# 20
# geracao 159
# Fitness= 9.823355322615509
# 20
# 20
# geracao 160
# Fitness= 9.823355322615509
# 20
# 20
# geracao 161
# Fitness= 9.823355322615509
# 20
# 20
# geracao 162
# Fitness= 9.823355322615509
# 20
# 20
# geracao 163
# Fitness= 9.823355322615509
# 20
# 20
# geracao 164
# Fitness= 9.823355322615509
# 20
# 20
# geracao 165
# Fitness= 9.823355322615509
# 20
# 20
# geracao 166
# Fitness= 9.823355322615509
# 20
# 20
# geracao 167
# Fitness= 9.823355322615509
# 20
# 20
# geracao 168
# Fitness= 9.823355322615509
# 20
# 20
# geracao 169
# Fitness= 9.823355322615509
# 20
# 20
# geracao 170
# Fitness= 9.823355322615509
# 20
# 20
# geracao 171
# Fitness= 9.823355322615509
# 20
# 20
# geracao 172
# Fitness= 9.823355322615509
# 20
# 20
# geracao 173
# Fitness= 9.823355322615509
# 20
# 20
# geracao 174
# Fitness= 9.823355322615509
# 20
# 20
# geracao 175
# Fitness= 9.823355322615509
# 20
# 20
# geracao 176
# Fitness= 9.823355322615509
# 20
# 20
# geracao 177
# Fitness= 9.823355322615509
# 20
# 20
# geracao 178
# Fitness= 9.823355322615509
# 20
# 20
# geracao 179
# Fitness= 9.814156040992392
# 20
# 20
# geracao 180
# Fitness= 9.814156040992392
# 20
# 20
# geracao 181
# Fitness= 9.814156040992392
# 20
# 20
# geracao 182
# Fitness= 9.814156040992392
# 20
# 20
# geracao 183
# Fitness= 9.814156040992392
# 20
# 20
# geracao 184
# Fitness= 9.814156040992392
# 20
# 20
# geracao 185
# Fitness= 9.814156040992392
# 20
# 20
# geracao 186
# Fitness= 9.814156040992392
# 20
# 20
# geracao 187
# Fitness= 9.814156040992392
# 20
# 20
# geracao 188
# Fitness= 9.814156040992392
# 20
# 20
# geracao 189
# Fitness= 9.814156040992392
# 20
# 20
# geracao 190
# Fitness= 9.814156040992392
# 20
# 20
# geracao 191
# Fitness= 9.814156040992392
# 20
# 20
# geracao 192
# Fitness= 9.814156040992392
# 20
# 20
# geracao 193
# Fitness= 9.814156040992392
# 20
# 20
# geracao 194
# Fitness= 9.814156040992392
# 20
# 20
# geracao 195
# Fitness= 9.814156040992392
# 20
# 20
# geracao 196
# Fitness= 9.814156040992392
# 20
# 20
# geracao 197
# Fitness= 9.777597443457243
# 20
# 20
# geracao 198
# Fitness= 9.777597443457243
# 20
# 20
# geracao 199
# Fitness= 9.777597443457243
# 20
# 20
# geracao 200
# Fitness= 9.777597443457243
# 20
# 20
# geracao 201
# Fitness= 9.777597443457243
# 20
# 20
# geracao 202
# Fitness= 9.777597443457243
# 20
# 20
# geracao 203
# Fitness= 9.777597443457243
# 20
# 20
# geracao 204
# Fitness= 9.777597443457243
# 20
# 20
# geracao 205
# Fitness= 9.777597443457243
# 20
# 20
# geracao 206
# Fitness= 9.777597443457243
# 20
# 20
# geracao 207
# Fitness= 9.777597443457243
# 20
# 20
# geracao 208
# Fitness= 9.777597443457243
# 20
# 20
# geracao 209
# Fitness= 9.777597443457243
# 20
# 20
# geracao 210
# Fitness= 9.777597443457243
# 20
# 20
# geracao 211
# Fitness= 9.777597443457243
# 20
# 20
# geracao 212
# Fitness= 9.777597443457243
# 20
# 20
# geracao 213
# Fitness= 9.777597443457243
# 20
# 20
# geracao 214
# Fitness= 9.777597443457243
# 20
# 20
# geracao 215
# Fitness= 9.777597443457243
# 20
# 20
# geracao 216
# Fitness= 9.341976989372743
# 20
# 20
# geracao 217
# Fitness= 9.341976989372743
# 20
# 20
# geracao 218
# Fitness= 9.341976989372743
# 20
# 20
# geracao 219
# Fitness= 9.341976989372743
# 20
# 20
# geracao 220
# Fitness= 9.341976989372743
# 20
# 20
# geracao 221
# Fitness= 9.341976989372743
# 20
# 20
# geracao 222
# Fitness= 9.341976989372743
# 20
# 20
# geracao 223
# Fitness= 9.341976989372743
# 20
# 20
# geracao 224
# Fitness= 9.341976989372743
# 20
# 20
# geracao 225
# Fitness= 9.341976989372743
# 20
# 20
# geracao 226
# Fitness= 9.341976989372743
# 20
# 20
# geracao 227
# Fitness= 9.341976989372743
# 20
# 20
# geracao 228
# Fitness= 9.341976989372743
# 20
# 20
# geracao 229
# Fitness= 9.33634420892454
# 20
# 20
# geracao 230
# Fitness= 9.33634420892454
# 20
# 20
# geracao 231
# Fitness= 9.33634420892454
# 20
# 20
# geracao 232
# Fitness= 9.33634420892454
# 20
# 20
# geracao 233
# Fitness= 9.33634420892454
# 20
# 20
# geracao 234
# Fitness= 9.33634420892454
# 20
# 20
# geracao 235
# Fitness= 9.33634420892454
# 20
# 20
# geracao 236
# Fitness= 9.33634420892454
# 20
# 20
# geracao 237
# Fitness= 9.33634420892454
# 20
# 20
# geracao 238
# Fitness= 9.33634420892454
# 20
# 20
# geracao 239
# Fitness= 9.33634420892454
# 20
# 20
# geracao 240
# Fitness= 9.33634420892454
# 20
# 20
# geracao 241
# Fitness= 9.33634420892454
# 20
# 20
# geracao 242
# Fitness= 9.33634420892454
# 20
# 20
# geracao 243
# Fitness= 9.33634420892454
# 20
# 20
# geracao 244
# Fitness= 9.33634420892454
# 20
# 20
# geracao 245
# Fitness= 9.33634420892454
# 20
# 20
# geracao 246
# Fitness= 9.33634420892454
# 20
# 20
# geracao 247
# Fitness= 9.33634420892454
# 20
# 20
# geracao 248
# Fitness= 9.33634420892454
# 20
# 20
# geracao 249
# Fitness= 9.33634420892454
# 20
# 20
# geracao 250
# Fitness= 9.329629734676004
# 20
# 20
# geracao 251
# Fitness= 9.329629734676004
# 20
# 20
# geracao 252
# Fitness= 9.329629734676004
# 20
# 20
# geracao 253
# Fitness= 9.329629734676004
# 20
# 20
# geracao 254
# Fitness= 9.329629734676004
# 20
# 20
# geracao 255
# Fitness= 9.329629734676004
# 20
# 20
# geracao 256
# Fitness= 9.329629734676004
# 20
# 20
# geracao 257
# Fitness= 9.329629734676004
# 20
# 20
# geracao 258
# Fitness= 9.329629734676004
# 20
# 20
# geracao 259
# Fitness= 9.329629734676004
# 20
# 20
# geracao 260
# Fitness= 9.329629734676004
# 20
# 20
# geracao 261
# Fitness= 9.329629734676004
# 20
# 20
# geracao 262
# Fitness= 9.329629734676004
# 20
# 20
# geracao 263
# Fitness= 9.329629734676004
# 20
# 20
# geracao 264
# Fitness= 9.329629734676004
# 20
# 20
# geracao 265
# Fitness= 9.329629734676004
# 20
# 20
# geracao 266
# Fitness= 9.329629734676004
# 20
# 20
# geracao 267
# Fitness= 9.235666274210866
# 20
# 20
# geracao 268
# Fitness= 9.235666274210866
# 20
# 20
# geracao 269
# Fitness= 9.235666274210866
# 20
# 20
# geracao 270
# Fitness= 9.067576223778838
# 20
# 20
# geracao 271
# Fitness= 9.067576223778838
# 20
# 20
# geracao 272
# Fitness= 9.067576223778838
# 20
# 20
# geracao 273
# Fitness= 8.978343522797129
# 20
# 20
# geracao 274
# Fitness= 8.978343522797129
# 20
# 20
# geracao 275
# Fitness= 8.978343522797129
# 20
# 20
# geracao 276
# Fitness= 8.978343522797129
# 20
# 20
# geracao 277
# Fitness= 8.978343522797129
# 20
# 20
# geracao 278
# Fitness= 8.978343522797129
# 20
# 20
# geracao 279
# Fitness= 8.628260354010191
# 20
# 20
# geracao 280
# Fitness= 8.628260354010191
# 20
# 20
# geracao 281
# Fitness= 8.5399834662187
# 20
# 20
# geracao 282
# Fitness= 8.5399834662187
# 20
# 20
# geracao 283
# Fitness= 8.5399834662187
# 20
# 20
# geracao 284
# Fitness= 8.20944579458281
# 20
# 20
# geracao 285
# Fitness= 8.20944579458281
# 20
# 20
# geracao 286
# Fitness= 8.20944579458281
# 20
# 20
# geracao 287
# Fitness= 8.20944579458281
# 20
# 20
# geracao 288
# Fitness= 8.204880686822754
# 20
# 20
# geracao 289
# Fitness= 8.204880686822754
# 20
# 20
# geracao 290
# Fitness= 8.204880686822754
# 20
# 20
# geracao 291
# Fitness= 7.898714518485084
# 20
# 20
# geracao 292
# Fitness= 7.898714518485084
# 20
# 20
# geracao 293
# Fitness= 7.898714518485084
# 20
# 20
# geracao 294
# Fitness= 7.898714518485084
# 20
# 20
# geracao 295
# Fitness= 7.898714518485084
# 20
# 20
# geracao 296
# Fitness= 7.898714518485084
# 20
# 20
# geracao 297
# Fitness= 7.898714518485084
# 20
# 20
# geracao 298
# Fitness= 7.898714518485084
# 20
# 20
# geracao 299
# Fitness= 7.898714518485084
# 20
# 20
# geracao 300
# Fitness= 7.898714518485084
# 20
# 20
# geracao 301
# Fitness= 7.898714518485084
# 20
# 20
# geracao 302
# Fitness= 7.898714518485084
# 20
# 20
# geracao 303
# Fitness= 7.898714518485084
# 20
# 20
# geracao 304
# Fitness= 7.898714518485084
# 20
# 20
# geracao 305
# Fitness= 7.898714518485084
# 20
# 20
# geracao 306
# Fitness= 7.898714518485084
# 20
# 20
# geracao 307
# Fitness= 7.898714518485084
# 20
# 20
# geracao 308
# Fitness= 7.898714518485084
# 20
# 20
# geracao 309
# Fitness= 7.898714518485084
# 20
# 20
# geracao 310
# Fitness= 7.898714518485084
# 20
# 20
# geracao 311
# Fitness= 7.898714518485084
# 20
# 20
# geracao 312
# Fitness= 7.898714518485084
# 20
# 20
# geracao 313
# Fitness= 7.898714518485084
# 20
# 20
# geracao 314
# Fitness= 7.898714518485084
# 20
# 20
# geracao 315
# Fitness= 7.898714518485084
# 20
# 20
# geracao 316
# Fitness= 7.898714518485084
# 20
# 20
# geracao 317
# Fitness= 7.898714518485084
# 20
# 20
# geracao 318
# Fitness= 7.898714518485084
# 20
# 20
# geracao 319
# Fitness= 7.898714518485084
# 20
# 20
# geracao 320
# Fitness= 7.898714518485084
# 20
# 20
# geracao 321
# Fitness= 7.898714518485084
# 20
# 20
# geracao 322
# Fitness= 7.898714518485084
# 20
# 20
# geracao 323
# Fitness= 7.898714518485084
# 20
# 20
# geracao 324
# Fitness= 7.898714518485084
# 20
# 20
# geracao 325
# Fitness= 7.898714518485084
# 20
# 20
# geracao 326
# Fitness= 7.898714518485084
# 20
# 20
# geracao 327
# Fitness= 7.898714518485084
# 20
# 20
# geracao 328
# Fitness= 7.898714518485084
# 20
# 20
# geracao 329
# Fitness= 7.875480530385016
# 20
# 20
# geracao 330
# Fitness= 7.875480530385016
# 20
# 20
# geracao 331
# Fitness= 7.875480530385016
# 20
# 20
# geracao 332
# Fitness= 7.875480530385016
# 20
# 20
# geracao 333
# Fitness= 7.875480530385016
# 20
# 20
# geracao 334
# Fitness= 7.875480530385016
# 20
# 20
# geracao 335
# Fitness= 7.875480530385016
# 20
# 20
# geracao 336
# Fitness= 7.819159212735767
# 20
# 20
# geracao 337
# Fitness= 7.819159212735767
# 20
# 20
# geracao 338
# Fitness= 7.819159212735767
# 20
# 20
# geracao 339
# Fitness= 7.819159212735767
# 20
# 20
# geracao 340
# Fitness= 7.819159212735767
# 20
# 20
# geracao 341
# Fitness= 7.819159212735767
# 20
# 20
# geracao 342
# Fitness= 7.819159212735767
# 20
# 20
# geracao 343
# Fitness= 7.819159212735767
# 20
# 20
# geracao 344
# Fitness= 7.819159212735767
# 20
# 20
# geracao 345
# Fitness= 7.819159212735767
# 20
# 20
# geracao 346
# Fitness= 7.819159212735767
# 20
# 20
# geracao 347
# Fitness= 7.819159212735767
# 20
# 20
# geracao 348
# Fitness= 7.819159212735767
# 20
# 20
# geracao 349
# Fitness= 7.759458130613652
# 20
# 20
# geracao 350
# Fitness= 7.759458130613652
# 20
# 20
# geracao 351
# Fitness= 7.759458130613652
# 20
# 20
# geracao 352
# Fitness= 7.759458130613652
# 20
# 20
# geracao 353
# Fitness= 7.759458130613652
# 20
# 20
# geracao 354
# Fitness= 7.759458130613652
# 20
# 20
# geracao 355
# Fitness= 7.759458130613652
# 20
# 20
# geracao 356
# Fitness= 7.759458130613652
# 20
# 20
# geracao 357
# Fitness= 7.759458130613652
# 20
# 20
# geracao 358
# Fitness= 7.759458130613652
# 20
# 20
# geracao 359
# Fitness= 7.759458130613652
# 20
# 20
# geracao 360
# Fitness= 7.759458130613652
# 20
# 20
# geracao 361
# Fitness= 7.759458130613652
# 20
# 20
# geracao 362
# Fitness= 7.759458130613652
# 20
# 20
# geracao 363
# Fitness= 7.759458130613652
# 20
# 20
# geracao 364
# Fitness= 7.759458130613652
# 20
# 20
# geracao 365
# Fitness= 7.759458130613652
# 20
# 20
# geracao 366
# Fitness= 7.759458130613652
# 20
# 20
# geracao 367
# Fitness= 7.759458130613652
# 20
# 20
# geracao 368
# Fitness= 7.759458130613652
# 20
# 20
# geracao 369
# Fitness= 7.759458130613652
# 20
# 20
# geracao 370
# Fitness= 7.759458130613652
# 20
# 20
# geracao 371
# Fitness= 7.759458130613652
# 20
# 20
# geracao 372
# Fitness= 7.759458130613652
# 20
# 20
# geracao 373
# Fitness= 7.759458130613652
# 20
# 20
# geracao 374
# Fitness= 7.759458130613652
# 20
# 20
# geracao 375
# Fitness= 7.759458130613652
# 20
# 20
# geracao 376
# Fitness= 7.759458130613652
# 20
# 20
# geracao 377
# Fitness= 7.759458130613652
# 20
# 20
# geracao 378
# Fitness= 7.759458130613652
# 20
# 20
# geracao 379
# Fitness= 7.759458130613652
# 20
# 20
# geracao 380
# Fitness= 7.759458130613652
# 20
# 20
# geracao 381
# Fitness= 7.759458130613652
# 20
# 20
# geracao 382
# Fitness= 7.759458130613652
# 20
# 20
# geracao 383
# Fitness= 7.759281567304512
# 20
# 20
# geracao 384
# Fitness= 7.759281567304512
# 20
# 20
# geracao 385
# Fitness= 7.759281567304512
# 20
# 20
# geracao 386
# Fitness= 7.759281567304512
# 20
# 20
# geracao 387
# Fitness= 7.759281567304512
# 20
# 20
# geracao 388
# Fitness= 7.759281567304512
# 20
# 20
# geracao 389
# Fitness= 7.759281567304512
# 20
# 20
# geracao 390
# Fitness= 7.759281567304512
# 20
# 20
# geracao 391
# Fitness= 7.759281567304512
# 20
# 20
# geracao 392
# Fitness= 7.759281567304512
# 20
# 20
# geracao 393
# Fitness= 7.759281567304512
# 20
# 20
# geracao 394
# Fitness= 7.759281567304512
# 20
# 20
# geracao 395
# Fitness= 7.759281567304512
# 20
# 20
# geracao 396
# Fitness= 7.754711535897719
# 20
# 20
# geracao 397
# Fitness= 7.754711535897719
# 20
# 20
# geracao 398
# Fitness= 7.754711535897719
# 20
# 20
# geracao 399
# Fitness= 7.754711535897719
# 20
# 20
# geracao 400
# Fitness= 7.754711535897719
# 20
# 20
# geracao 401
# Fitness= 7.754711535897719
# 20
# 20
# geracao 402
# Fitness= 7.754711535897719
# 20
# 20
# geracao 403
# Fitness= 7.754711535897719
# 20
# 20
# geracao 404
# Fitness= 7.754711535897719
# 20
# 20
# geracao 405
# Fitness= 7.754711535897719
# 20
# 20
# geracao 406
# Fitness= 7.754711535897719
# 20
# 20
# geracao 407
# Fitness= 7.754711535897719
# 20
# 20
# geracao 408
# Fitness= 7.754711535897719
# 20
# 20
# geracao 409
# Fitness= 7.754711535897719
# 20
# 20
# geracao 410
# Fitness= 7.754711535897719
# 20
# 20
# geracao 411
# Fitness= 7.754711535897719
# 20
# 20
# geracao 412
# Fitness= 7.754711535897719
# 20
# 20
# geracao 413
# Fitness= 7.754711535897719
# 20
# 20
# geracao 414
# Fitness= 7.754711535897719
# 20
# 20
# geracao 415
# Fitness= 7.754711535897719
# 20
# 20
# geracao 416
# Fitness= 7.754711535897719
# 20
# 20
# geracao 417
# Fitness= 7.754711535897719
# 20
# 20
# geracao 418
# Fitness= 7.754711535897719
# 20
# 20
# geracao 419
# Fitness= 7.754711535897719
# 20
# 20
# geracao 420
# Fitness= 7.754711535897719
# 20
# 20
# geracao 421
# Fitness= 7.754711535897719
# 20
# 20
# geracao 422
# Fitness= 7.754711535897719
# 20
# 20
# geracao 423
# Fitness= 7.754711535897719
# 20
# 20
# geracao 424
# Fitness= 7.754711535897719
# 20
# 20
# geracao 425
# Fitness= 7.754711535897719
# 20
# 20
# geracao 426
# Fitness= 7.754711535897719
# 20
# 20
# geracao 427
# Fitness= 7.754711535897719
# 20
# 20
# geracao 428
# Fitness= 7.754711535897719
# 20
# 20
# geracao 429
# Fitness= 7.754711535897719
# 20
# 20
# geracao 430
# Fitness= 7.754711535897719
# 20
# 20
# geracao 431
# Fitness= 7.754711535897719
# 20
# 20
# geracao 432
# Fitness= 7.754711535897719
# 20
# 20
# geracao 433
# Fitness= 7.754711535897719
# 20
# 20
# geracao 434
# Fitness= 7.754711535897719
# 20
# 20
# geracao 435
# Fitness= 7.754711535897719
# 20
# 20
# geracao 436
# Fitness= 7.754711535897719
# 20
# 20
# geracao 437
# Fitness= 7.754711535897719
# 20
# 20
# geracao 438
# Fitness= 7.754711535897719
# 20
# 20
# geracao 439
# Fitness= 7.754711535897719
# 20
# 20
# geracao 440
# Fitness= 7.754711535897719
# 20
# 20
# geracao 441
# Fitness= 7.754711535897719
# 20
# 20
# geracao 442
# Fitness= 7.754711535897719
# 20
# 20
# geracao 443
# Fitness= 7.754711535897719
# 20
# 20
# geracao 444
# Fitness= 7.754711535897719
# 20
# 20
# geracao 445
# Fitness= 7.754711535897719
# 20
# 20
# geracao 446
# Fitness= 7.754711535897719
# 20
# 20
# geracao 447
# Fitness= 7.754711535897719
# 20
# 20
# geracao 448
# Fitness= 7.754711535897719
# 20
# 20
# geracao 449
# Fitness= 7.754711535897719
# 20
# 20
# geracao 450
# Fitness= 7.754711535897719
# 20
# 20
# geracao 451
# Fitness= 7.754711535897719
# 20
# 20
# geracao 452
# Fitness= 7.754711535897719
# 20
# 20
# geracao 453
# Fitness= 7.754711535897719
# 20
# 20
# geracao 454
# Fitness= 7.754711535897719
# 20
# 20
# geracao 455
# Fitness= 7.754711535897719
# 20
# 20
# geracao 456
# Fitness= 7.092334167096797
# 20
# 20
# geracao 457
# Fitness= 7.092334167096797
# 20
# 20
# geracao 458
# Fitness= 7.092334167096797
# 20
# 20
# geracao 459
# Fitness= 7.092334167096797
# 20
# 20
# geracao 460
# Fitness= 7.092334167096797
# 20
# 20
# geracao 461
# Fitness= 7.092334167096797
# 20
# 20
# geracao 462
# Fitness= 7.085184765537494
# 20
# 20
# geracao 463
# Fitness= 7.085184765537494
# 20
# 20
# geracao 464
# Fitness= 7.085184765537494
# 20
# 20
# geracao 465
# Fitness= 7.085184765537494
# 20
# 20
# geracao 466
# Fitness= 7.085184765537494
# 20
# 20
# geracao 467
# Fitness= 7.085184765537494
# 20
# 20
# geracao 468
# Fitness= 7.085184765537494
# 20
# 20
# geracao 469
# Fitness= 7.085184765537494
# 20
# 20
# geracao 470
# Fitness= 7.085184765537494
# 20
# 20
# geracao 471
# Fitness= 7.085184765537494
# 20
# 20
# geracao 472
# Fitness= 7.085184765537494
# 20
# 20
# geracao 473
# Fitness= 7.085184765537494
# 20
# 20
# geracao 474
# Fitness= 7.085184765537494
# 20
# 20
# geracao 475
# Fitness= 6.637787848371369
# 20
# 20
# geracao 476
# Fitness= 6.637787848371369
# 20
# 20
# geracao 477
# Fitness= 6.637787848371369
# 20
# 20
# geracao 478
# Fitness= 6.637787848371369
# 20
# 20
# geracao 479
# Fitness= 6.637787848371369
# 20
# 20
# geracao 480
# Fitness= 6.637787848371369
# 20
# 20
# geracao 481
# Fitness= 6.637787848371369
# 20
# 20
# geracao 482
# Fitness= 6.637787848371369
# 20
# 20
# geracao 483
# Fitness= 6.637787848371369
# 20
# 20
# geracao 484
# Fitness= 6.637787848371369
# 20
# 20
# geracao 485
# Fitness= 6.637787848371369
# 20
# 20
# geracao 486
# Fitness= 6.637787848371369
# 20
# 20
# geracao 487
# Fitness= 6.637787848371369
# 20
# 20
# geracao 488
# Fitness= 6.637787848371369
# 20
# 20
# geracao 489
# Fitness= 6.637787848371369
# 20
# 20
# geracao 490
# Fitness= 6.637787848371369
# 20
# 20
# geracao 491
# Fitness= 6.637787848371369
# 20
# 20
# geracao 492
# Fitness= 6.637787848371369
# 20
# 20
# geracao 493
# Fitness= 6.637225570600668
# 20
# 20
# geracao 494
# Fitness= 6.637225570600668
# 20
# 20
# geracao 495
# Fitness= 6.637225570600668
# 20
# 20
# geracao 496
# Fitness= 6.637225570600668
# 20
# 20
# geracao 497
# Fitness= 6.637225570600668
# 20
# 20
# geracao 498
# Fitness= 6.637225570600668
# 20
# 20
# geracao 499
# Fitness= 6.637225570600668
# 20
# 20
# geracao 500
# Fitness= 6.637225570600668
# 20
# 20
# geracao 501
# Fitness= 6.637225570600668
# 20
# 20
# geracao 502
# Fitness= 6.637225570600668
# 20
# 20
# geracao 503
# Fitness= 6.637225570600668
# 20
# 20
# geracao 504
# Fitness= 6.634341212359675
# 20
# 20
# geracao 505
# Fitness= 6.634341212359675
# 20
# 20
# geracao 506
# Fitness= 6.634341212359675
# 20
# 20
# geracao 507
# Fitness= 6.634341212359675
# 20
# 20
# geracao 508
# Fitness= 6.634341212359675
# 20
# 20
# geracao 509
# Fitness= 6.634341212359675
# 20
# 20
# geracao 510
# Fitness= 6.634341212359675
# 20
# 20
# geracao 511
# Fitness= 6.634341212359675
# 20
# 20
# geracao 512
# Fitness= 6.634341212359675
# 20
# 20
# geracao 513
# Fitness= 6.634341212359675
# 20
# 20
# geracao 514
# Fitness= 6.634341212359675
# 20
# 20
# geracao 515
# Fitness= 6.634341212359675
# 20
# 20
# geracao 516
# Fitness= 6.634341212359675
# 20
# 20
# geracao 517
# Fitness= 6.632740707475063
# 20
# 20
# geracao 518
# Fitness= 6.632740707475063
# 20
# 20
# geracao 519
# Fitness= 6.632740707475063
# 20
# 20
# geracao 520
# Fitness= 6.632740707475063
# 20
# 20
# geracao 521
# Fitness= 6.632740707475063
# 20
# 20
# geracao 522
# Fitness= 6.632740707475063
# 20
# 20
# geracao 523
# Fitness= 6.632740707475063
# 20
# 20
# geracao 524
# Fitness= 6.632740707475063
# 20
# 20
# geracao 525
# Fitness= 6.632740707475063
# 20
# 20
# geracao 526
# Fitness= 6.632740707475063
# 20
# 20
# geracao 527
# Fitness= 6.632740707475063
# 20
# 20
# geracao 528
# Fitness= 6.632740707475063
# 20
# 20
# geracao 529
# Fitness= 6.632740707475063
# 20
# 20
# geracao 530
# Fitness= 6.632740707475063
# 20
# 20
# geracao 531
# Fitness= 6.472320316462603
# 20
# 20
# geracao 532
# Fitness= 6.472320316462603
# 20
# 20
# geracao 533
# Fitness= 6.472320316462603
# 20
# 20
# geracao 534
# Fitness= 6.472320316462603
# 20
# 20
# geracao 535
# Fitness= 6.472320316462603
# 20
# 20
# geracao 536
# Fitness= 6.472320316462603
# 20
# 20
# geracao 537
# Fitness= 6.472320316462603
# 20
# 20
# geracao 538
# Fitness= 6.472320316462603
# 20
# 20
# geracao 539
# Fitness= 6.472320316462603
# 20
# 20
# geracao 540
# Fitness= 6.472320316462603
# 20
# 20
# geracao 541
# Fitness= 6.472320316462603
# 20
# 20
# geracao 542
# Fitness= 6.472320316462603
# 20
# 20
# geracao 543
# Fitness= 6.472320316462603
# 20
# 20
# geracao 544
# Fitness= 6.472320316462603
# 20
# 20
# geracao 545
# Fitness= 6.472320316462603
# 20
# 20
# geracao 546
# Fitness= 6.472320316462603
# 20
# 20
# geracao 547
# Fitness= 6.472320316462603
# 20
# 20
# geracao 548
# Fitness= 6.472320316462603
# 20
# 20
# geracao 549
# Fitness= 6.472320316462603
# 20
# 20
# geracao 550
# Fitness= 6.472320316462603
# 20
# 20
# geracao 551
# Fitness= 6.470141176131127
# 20
# 20
# geracao 552
# Fitness= 6.470141176131127
# 20
# 20
# geracao 553
# Fitness= 6.470141176131127
# 20
# 20
# geracao 554
# Fitness= 6.470141176131127
# 20
# 20
# geracao 555
# Fitness= 6.405547762224113
# 20
# 20
# geracao 556
# Fitness= 6.405547762224113
# 20
# 20
# geracao 557
# Fitness= 6.405547762224113
# 20
# 20
# geracao 558
# Fitness= 6.405547762224113
# 20
# 20
# geracao 559
# Fitness= 6.405547762224113
# 20
# 20
# geracao 560
# Fitness= 6.405547762224113
# 20
# 20
# geracao 561
# Fitness= 6.403152646593023
# 20
# 20
# geracao 562
# Fitness= 6.403152646593023
# 20
# 20
# geracao 563
# Fitness= 6.403152646593023
# 20
# 20
# geracao 564
# Fitness= 6.403152646593023
# 20
# 20
# geracao 565
# Fitness= 6.403152646593023
# 20
# 20
# geracao 566
# Fitness= 6.403152646593023
# 20
# 20
# geracao 567
# Fitness= 6.403152646593023
# 20
# 20
# geracao 568
# Fitness= 6.403152646593023
# 20
# 20
# geracao 569
# Fitness= 6.403152646593023
# 20
# 20
# geracao 570
# Fitness= 6.403152646593023
# 20
# 20
# geracao 571
# Fitness= 6.403152646593023
# 20
# 20
# geracao 572
# Fitness= 6.396900282836226
# 20
# 20
# geracao 573
# Fitness= 6.396900282836226
# 20
# 20
# geracao 574
# Fitness= 6.396900282836226
# 20
# 20
# geracao 575
# Fitness= 6.396900282836226
# 20
# 20
# geracao 576
# Fitness= 6.396900282836226
# 20
# 20
# geracao 577
# Fitness= 6.396900282836226
# 20
# 20
# geracao 578
# Fitness= 6.396900282836226
# 20
# 20
# geracao 579
# Fitness= 6.396900282836226
# 20
# 20
# geracao 580
# Fitness= 6.396900282836226
# 20
# 20
# geracao 581
# Fitness= 6.396900282836226
# 20
# 20
# geracao 582
# Fitness= 6.396900282836226
# 20
# 20
# geracao 583
# Fitness= 6.396900282836226
# 20
# 20
# geracao 584
# Fitness= 6.396900282836226
# 20
# 20
# geracao 585
# Fitness= 6.396900282836226
# 20
# 20
# geracao 586
# Fitness= 6.396900282836226
# 20
# 20
# geracao 587
# Fitness= 6.396900282836226
# 20
# 20
# geracao 588
# Fitness= 6.396900282836226
# 20
# 20
# geracao 589
# Fitness= 6.394860834376873
# 20
# 20
# geracao 590
# Fitness= 6.394860834376873
# 20
# 20
# geracao 591
# Fitness= 6.394860834376873
# 20
# 20
# geracao 592
# Fitness= 6.394860834376873
# 20
# 20
# geracao 593
# Fitness= 6.394860834376873
# 20
# 20
# geracao 594
# Fitness= 6.394860834376873
# 20
# 20
# geracao 595
# Fitness= 6.394860834376873
# 20
# 20
# geracao 596
# Fitness= 6.394860834376873
# 20
# 20
# geracao 597
# Fitness= 6.394860834376873
# 20
# 20
# geracao 598
# Fitness= 6.394860834376873
# 20
# 20
# geracao 599
# Fitness= 6.394860834376873
# 20
# 20
# geracao 600
# Fitness= 6.394860834376873
# 20
# 20
# geracao 601
# Fitness= 6.394860834376873
# 20
# 20
# geracao 602
# Fitness= 6.394860834376873
# 20
# 20
# geracao 603
# Fitness= 6.394860834376873
# 20
# 20
# geracao 604
# Fitness= 6.394860834376873
# 20
# 20
# geracao 605
# Fitness= 6.394860834376873
# 20
# 20
# geracao 606
# Fitness= 6.394860834376873
# 20
# 20
# geracao 607
# Fitness= 6.394860834376873
# 20
# 20
# geracao 608
# Fitness= 6.394860834376873
# 20
# 20
# geracao 609
# Fitness= 6.177892857852946
# 20
# 20
# geracao 610
# Fitness= 6.177892857852946
# 20
# 20
# geracao 611
# Fitness= 6.177892857852946
# 20
# 20
# geracao 612
# Fitness= 6.177892857852946
# 20
# 20
# geracao 613
# Fitness= 6.177892857852946
# 20
# 20
# geracao 614
# Fitness= 6.177892857852946
# 20
# 20
# geracao 615
# Fitness= 6.177892857852946
# 20
# 20
# geracao 616
# Fitness= 6.177892857852946
# 20
# 20
# geracao 617
# Fitness= 6.177892857852946
# 20
# 20
# geracao 618
# Fitness= 6.177892857852946
# 20
# 20
# geracao 619
# Fitness= 6.177892857852946
# 20
# 20
# geracao 620
# Fitness= 6.177892857852946
# 20
# 20
# geracao 621
# Fitness= 6.177892857852946
# 20
# 20
# geracao 622
# Fitness= 6.177892857852946
# 20
# 20
# geracao 623
# Fitness= 6.177892857852946
# 20
# 20
# geracao 624
# Fitness= 6.172688569060854
# 20
# 20
# geracao 625
# Fitness= 6.172688569060854
# 20
# 20
# geracao 626
# Fitness= 6.172688569060854
# 20
# 20
# geracao 627
# Fitness= 6.172688569060854
# 20
# 20
# geracao 628
# Fitness= 6.172688569060854
# 20
# 20
# geracao 629
# Fitness= 6.172688569060854
# 20
# 20
# geracao 630
# Fitness= 6.172688569060854
# 20
# 20
# geracao 631
# Fitness= 6.172688569060854
# 20
# 20
# geracao 632
# Fitness= 6.172688569060854
# 20
# 20
# geracao 633
# Fitness= 6.172688569060854
# 20
# 20
# geracao 634
# Fitness= 6.172688569060854
# 20
# 20
# geracao 635
# Fitness= 6.172688569060854
# 20
# 20
# geracao 636
# Fitness= 6.172688569060854
# 20
# 20
# geracao 637
# Fitness= 6.172688569060854
# 20
# 20
# geracao 638
# Fitness= 6.172688569060854
# 20
# 20
# geracao 639
# Fitness= 6.172688569060854
# 20
# 20
# geracao 640
# Fitness= 6.172688569060854
# 20
# 20
# geracao 641
# Fitness= 6.172688569060854
# 20
# 20
# geracao 642
# Fitness= 6.172688569060854
# 20
# 20
# geracao 643
# Fitness= 6.172688569060854
# 20
# 20
# geracao 644
# Fitness= 6.172688569060854
# 20
# 20
# geracao 645
# Fitness= 6.172688569060854
# 20
# 20
# geracao 646
# Fitness= 6.172688569060854
# 20
# 20
# geracao 647
# Fitness= 6.172688569060854
# 20
# 20
# geracao 648
# Fitness= 6.172688569060854
# 20
# 20
# geracao 649
# Fitness= 6.172688569060854
# 20
# 20
# geracao 650
# Fitness= 6.168213900591415
# 20
# 20
# geracao 651
# Fitness= 6.168213900591415
# 20
# 20
# geracao 652
# Fitness= 6.168213900591415
# 20
# 20
# geracao 653
# Fitness= 6.168213900591415
# 20
# 20
# geracao 654
# Fitness= 6.168213900591415
# 20
# 20
# geracao 655
# Fitness= 6.168213900591415
# 20
# 20
# geracao 656
# Fitness= 6.168213900591415
# 20
# 20
# geracao 657
# Fitness= 6.168213900591415
# 20
# 20
# geracao 658
# Fitness= 6.168213900591415
# 20
# 20
# geracao 659
# Fitness= 6.168213900591415
# 20
# 20
# geracao 660
# Fitness= 6.168213900591415
# 20
# 20
# geracao 661
# Fitness= 6.168213900591415
# 20
# 20
# geracao 662
# Fitness= 6.168213900591415
# 20
# 20
# geracao 663
# Fitness= 6.168213900591415
# 20
# 20
# geracao 664
# Fitness= 6.168213900591415
# 20
# 20
# geracao 665
# Fitness= 6.168213900591415
# 20
# 20
# geracao 666
# Fitness= 6.168213900591415
# 20
# 20
# geracao 667
# Fitness= 6.168213900591415
# 20
# 20
# geracao 668
# Fitness= 6.168213900591415
# 20
# 20
# geracao 669
# Fitness= 6.168213900591415
# 20
# 20
# geracao 670
# Fitness= 6.168213900591415
# 20
# 20
# geracao 671
# Fitness= 6.168213900591415
# 20
# 20
# geracao 672
# Fitness= 6.168213900591415
# 20
# 20
# geracao 673
# Fitness= 6.168213900591415
# 20
# 20
# geracao 674
# Fitness= 6.168213900591415
# 20
# 20
# geracao 675
# Fitness= 6.168213900591415
# 20
# 20
# geracao 676
# Fitness= 6.168213900591415
# 20
# 20
# geracao 677
# Fitness= 6.168213900591415
# 20
# 20
# geracao 678
# Fitness= 6.168213900591415
# 20
# 20
# geracao 679
# Fitness= 6.168213900591415
# 20
# 20
# geracao 680
# Fitness= 6.168213900591415
# 20
# 20
# geracao 681
# Fitness= 6.168213900591415
# 20
# 20
# geracao 682
# Fitness= 6.168213900591415
# 20
# 20
# geracao 683
# Fitness= 6.168213900591415
# 20
# 20
# geracao 684
# Fitness= 6.168213900591415
# 20
# 20
# geracao 685
# Fitness= 6.168213900591415
# 20
# 20
# geracao 686
# Fitness= 6.168213900591415
# 20
# 20
# geracao 687
# Fitness= 6.168213900591415
# 20
# 20
# geracao 688
# Fitness= 6.168213900591415
# 20
# 20
# geracao 689
# Fitness= 6.168213900591415
# 20
# 20
# geracao 690
# Fitness= 6.168213900591415
# 20
# 20
# geracao 691
# Fitness= 6.168213900591415
# 20
# 20
# geracao 692
# Fitness= 5.826991310863294
# 20
# 20
# geracao 693
# Fitness= 5.826991310863294
# 20
# 20
# geracao 694
# Fitness= 5.826991310863294
# 20
# 20
# geracao 695
# Fitness= 5.826991310863294
# 20
# 20
# geracao 696
# Fitness= 5.826991310863294
# 20
# 20
# geracao 697
# Fitness= 5.826991310863294
# 20
# 20
# geracao 698
# Fitness= 5.826991310863294
# 20
# 20
# geracao 699
# Fitness= 5.826991310863294
# 20
# 20
# geracao 700
# Fitness= 5.826991310863294
# 20
# 20
# geracao 701
# Fitness= 5.826991310863294
# 20
# 20
# geracao 702
# Fitness= 5.826991310863294
# 20
# 20
# geracao 703
# Fitness= 5.826991310863294
# 20
# 20
# geracao 704
# Fitness= 5.826991310863294
# 20
# 20
# geracao 705
# Fitness= 5.826991310863294
# 20
# 20
# geracao 706
# Fitness= 5.826991310863294
# 20
# 20
# geracao 707
# Fitness= 5.826991310863294
# 20
# 20
# geracao 708
# Fitness= 5.826991310863294
# 20
# 20
# geracao 709
# Fitness= 5.826991310863294
# 20
# 20
# geracao 710
# Fitness= 5.826991310863294
# 20
# 20
# geracao 711
# Fitness= 5.826991310863294
# 20
# 20
# geracao 712
# Fitness= 5.826991310863294
# 20
# 20
# geracao 713
# Fitness= 5.826991310863294
# 20
# 20
# geracao 714
# Fitness= 5.826991310863294
# 20
# 20
# geracao 715
# Fitness= 5.826991310863294
# 20
# 20
# geracao 716
# Fitness= 5.826991310863294
# 20
# 20
# geracao 717
# Fitness= 5.826991310863294
# 20
# 20
# geracao 718
# Fitness= 5.826991310863294
# 20
# 20
# geracao 719
# Fitness= 5.826991310863294
# 20
# 20
# geracao 720
# Fitness= 5.826991310863294
# 20
# 20
# geracao 721
# Fitness= 5.826991310863294
# 20
# 20
# geracao 722
# Fitness= 5.826991310863294
# 20
# 20
# geracao 723
# Fitness= 5.759326970429532
# 20
# 20
# geracao 724
# Fitness= 5.759326970429532
# 20
# 20
# geracao 725
# Fitness= 5.759326970429532
# 20
# 20
# geracao 726
# Fitness= 5.759326970429532
# 20
# 20
# geracao 727
# Fitness= 5.759326970429532
# 20
# 20
# geracao 728
# Fitness= 5.759326970429532
# 20
# 20
# geracao 729
# Fitness= 5.759326970429532
# 20
# 20
# geracao 730
# Fitness= 5.759326970429532
# 20
# 20
# geracao 731
# Fitness= 5.759326970429532
# 20
# 20
# geracao 732
# Fitness= 5.759326970429532
# 20
# 20
# geracao 733
# Fitness= 5.759326970429532
# 20
# 20
# geracao 734
# Fitness= 5.759326970429532
# 20
# 20
# geracao 735
# Fitness= 5.759326970429532
# 20
# 20
# geracao 736
# Fitness= 5.759326970429532
# 20
# 20
# geracao 737
# Fitness= 5.759326970429532
# 20
# 20
# geracao 738
# Fitness= 5.759326970429532
# 20
# 20
# geracao 739
# Fitness= 5.759326970429532
# 20
# 20
# geracao 740
# Fitness= 5.759326970429532
# 20
# 20
# geracao 741
# Fitness= 5.759326970429532
# 20
# 20
# geracao 742
# Fitness= 5.759326970429532
# 20
# 20
# geracao 743
# Fitness= 5.759326970429532
# 20
# 20
# geracao 744
# Fitness= 5.759326970429532
# 20
# 20
# geracao 745
# Fitness= 5.759326970429532
# 20
# 20
# geracao 746
# Fitness= 5.758423499137183
# 20
# 20
# geracao 747
# Fitness= 5.758423499137183
# 20
# 20
# geracao 748
# Fitness= 5.758423499137183
# 20
# 20
# geracao 749
# Fitness= 5.758423499137183
# 20
# 20
# geracao 750
# Fitness= 5.758423499137183
# 20
# 20
# geracao 751
# Fitness= 5.758423499137183
# 20
# 20
# geracao 752
# Fitness= 5.758423499137183
# 20
# 20
# geracao 753
# Fitness= 5.745451076320178
# 20
# 20
# geracao 754
# Fitness= 5.745451076320178
# 20
# 20
# geracao 755
# Fitness= 5.745451076320178
# 20
# 20
# geracao 756
# Fitness= 5.745451076320178
# 20
# 20
# geracao 757
# Fitness= 5.745451076320178
# 20
# 20
# geracao 758
# Fitness= 5.745451076320178
# 20
# 20
# geracao 759
# Fitness= 5.745451076320178
# 20
# 20
# geracao 760
# Fitness= 5.745451076320178
# 20
# 20
# geracao 761
# Fitness= 5.745451076320178
# 20
# 20
# geracao 762
# Fitness= 5.745451076320178
# 20
# 20
# geracao 763
# Fitness= 5.745451076320178
# 20
# 20
# geracao 764
# Fitness= 5.745451076320178
# 20
# 20
# geracao 765
# Fitness= 5.745451076320178
# 20
# 20
# geracao 766
# Fitness= 5.745451076320178
# 20
# 20
# geracao 767
# Fitness= 5.745451076320178
# 20
# 20
# geracao 768
# Fitness= 5.745451076320178
# 20
# 20
# geracao 769
# Fitness= 5.745451076320178
# 20
# 20
# geracao 770
# Fitness= 5.744264205058174
# 20
# 20
# geracao 771
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 772
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 773
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 774
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 775
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 776
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 777
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 778
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 779
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 780
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 781
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 782
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 783
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 784
# Fitness= 5.7391651715198515
# 20
# 20
# geracao 785
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 786
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 787
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 788
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 789
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 790
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 791
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 792
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 793
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 794
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 795
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 796
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 797
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 798
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 799
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 800
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 801
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 802
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 803
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 804
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 805
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 806
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 807
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 808
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 809
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 810
# Fitness= 5.6485989983073726
# 20
# 20
# geracao 811
# Fitness= 5.632109380690498
# 20
# 20
# geracao 812
# Fitness= 5.632109380690498
# 20
# 20
# geracao 813
# Fitness= 5.632109380690498
# 20
# 20
# geracao 814
# Fitness= 5.632109380690498
# 20
# 20
# geracao 815
# Fitness= 5.632109380690498
# 20
# 20
# geracao 816
# Fitness= 5.632109380690498
# 20
# 20
# geracao 817
# Fitness= 5.632109380690498
# 20
# 20
# geracao 818
# Fitness= 5.629284581048412
# 20
# 20
# geracao 819
# Fitness= 5.629284581048412
# 20
# 20
# geracao 820
# Fitness= 5.629284581048412
# 20
# 20
# geracao 821
# Fitness= 5.629284581048412
# 20
# 20
# geracao 822
# Fitness= 5.629284581048412
# 20
# 20
# geracao 823
# Fitness= 5.629284581048412
# 20
# 20
# geracao 824
# Fitness= 5.629284581048412
# 20
# 20
# geracao 825
# Fitness= 5.629284581048412
# 20
# 20
# geracao 826
# Fitness= 5.629284581048412
# 20
# 20
# geracao 827
# Fitness= 5.605736492345337
# 20
# 20
# geracao 828
# Fitness= 5.605736492345337
# 20
# 20
# geracao 829
# Fitness= 5.605736492345337
# 20
# 20
# geracao 830
# Fitness= 5.605736492345337
# 20
# 20
# geracao 831
# Fitness= 5.605736492345337
# 20
# 20
# geracao 832
# Fitness= 5.605736492345337
# 20
# 20
# geracao 833
# Fitness= 5.605736492345337
# 20
# 20
# geracao 834
# Fitness= 5.605736492345337
# 20
# 20
# geracao 835
# Fitness= 5.605736492345337
# 20
# 20
# geracao 836
# Fitness= 5.605736492345337
# 20
# 20
# geracao 837
# Fitness= 5.605736492345337
# 20
# 20
# geracao 838
# Fitness= 5.605736492345337
# 20
# 20
# geracao 839
# Fitness= 5.605736492345337
# 20
# 20
# geracao 840
# Fitness= 5.605736492345337
# 20
# 20
# geracao 841
# Fitness= 5.605736492345337
# 20
# 20
# geracao 842
# Fitness= 5.605736492345337
# 20
# 20
# geracao 843
# Fitness= 5.605736492345337
# 20
# 20
# geracao 844
# Fitness= 5.605736492345337
# 20
# 20
# geracao 845
# Fitness= 5.605736492345337
# 20
# 20
# geracao 846
# Fitness= 5.605736492345337
# 20
# 20
# geracao 847
# Fitness= 5.605736492345337
# 20
# 20
# geracao 848
# Fitness= 5.605736492345337
# 20
# 20
# geracao 849
# Fitness= 5.605736492345337
# 20
# 20
# geracao 850
# Fitness= 5.605736492345337
# 20
# 20
# geracao 851
# Fitness= 5.605736492345337
# 20
# 20
# geracao 852
# Fitness= 5.605736492345337
# 20
# 20
# geracao 853
# Fitness= 5.605736492345337
# 20
# 20
# geracao 854
# Fitness= 5.605736492345337
# 20
# 20
# geracao 855
# Fitness= 5.605736492345337
# 20
# 20
# geracao 856
# Fitness= 5.602372359908641
# 20
# 20
# geracao 857
# Fitness= 5.602372359908641
# 20
# 20
# geracao 858
# Fitness= 5.602372359908641
# 20
# 20
# geracao 859
# Fitness= 5.602372359908641
# 20
# 20
# geracao 860
# Fitness= 5.602372359908641
# 20
# 20
# geracao 861
# Fitness= 5.602372359908641
# 20
# 20
# geracao 862
# Fitness= 5.602372359908641
# 20
# 20
# geracao 863
# Fitness= 5.6000421325208665
# 20
# 20
# geracao 864
# Fitness= 5.6000421325208665
# 20
# 20
# geracao 865
# Fitness= 5.6000421325208665
# 20
# 20
# geracao 866
# Fitness= 5.599433358128066
# 20
# 20
# geracao 867
# Fitness= 5.599433358128066
# 20
# 20
# geracao 868
# Fitness= 5.585491979691918
# 20
# 20
# geracao 869
# Fitness= 5.585491979691918
# 20
# 20
# geracao 870
# Fitness= 5.58335876860617
# 20
# 20
# geracao 871
# Fitness= 5.58335876860617
# 20
# 20
# geracao 872
# Fitness= 5.58335876860617
# 20
# 20
# geracao 873
# Fitness= 5.58335876860617
# 20
# 20
# geracao 874
# Fitness= 5.583131744540668
# 20
# 20
# geracao 875
# Fitness= 5.583131744540668
# 20
# 20
# geracao 876
# Fitness= 5.583131744540668
# 20
# 20
# geracao 877
# Fitness= 5.583131744540668
# 20
# 20
# geracao 878
# Fitness= 5.583131744540668
# 20
# 20
# geracao 879
# Fitness= 5.583131744540668
# 20
# 20
# geracao 880
# Fitness= 5.583131744540668
# 20
# 20
# geracao 881
# Fitness= 5.583131744540668
# 20
# 20
# geracao 882
# Fitness= 5.583131744540668
# 20
# 20
# geracao 883
# Fitness= 5.583131744540668
# 20
# 20
# geracao 884
# Fitness= 5.583131744540668
# 20
# 20
# geracao 885
# Fitness= 5.583131744540668
# 20
# 20
# geracao 886
# Fitness= 5.583131744540668
# 20
# 20
# geracao 887
# Fitness= 5.583131744540668
# 20
# 20
# geracao 888
# Fitness= 5.583131744540668
# 20
# 20
# geracao 889
# Fitness= 5.583131744540668
# 20
# 20
# geracao 890
# Fitness= 5.583131744540668
# 20
# 20
# geracao 891
# Fitness= 5.583131744540668
# 20
# 20
# geracao 892
# Fitness= 5.583131744540668
# 20
# 20
# geracao 893
# Fitness= 5.583131744540668
# 20
# 20
# geracao 894
# Fitness= 5.583131744540668
# 20
# 20
# geracao 895
# Fitness= 5.583131744540668
# 20
# 20
# geracao 896
# Fitness= 5.583131744540668
# 20
# 20
# geracao 897
# Fitness= 5.583131744540668
# 20
# 20
# geracao 898
# Fitness= 5.566748770222024
# 20
# 20
# geracao 899
# Fitness= 5.566748770222024
# 20
# 20
# geracao 900
# Fitness= 5.566748770222024
# 20
# 20
# geracao 901
# Fitness= 5.566748770222024
# 20
# 20
# geracao 902
# Fitness= 5.566748770222024
# 20
# 20
# geracao 903
# Fitness= 5.566602206818148
# 20
# 20
# geracao 904
# Fitness= 5.566602206818148
# 20
# 20
# geracao 905
# Fitness= 5.566602206818148
# 20
# 20
# geracao 906
# Fitness= 5.566602206818148
# 20
# 20
# geracao 907
# Fitness= 5.566602206818148
# 20
# 20
# geracao 908
# Fitness= 5.566602206818148
# 20
# 20
# geracao 909
# Fitness= 5.566602206818148
# 20
# 20
# geracao 910
# Fitness= 5.566602206818148
# 20
# 20
# geracao 911
# Fitness= 5.566602206818148
# 20
# 20
# geracao 912
# Fitness= 5.51535488366866
# 20
# 20
# geracao 913
# Fitness= 5.51535488366866
# 20
# 20
# geracao 914
# Fitness= 5.51535488366866
# 20
# 20
# geracao 915
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 916
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 917
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 918
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 919
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 920
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 921
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 922
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 923
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 924
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 925
# Fitness= 5.5152418154165685
# 20
# 20
# geracao 926
# Fitness= 5.507945739999867
# 20
# 20
# geracao 927
# Fitness= 5.507945739999867
# 20
# 20
# geracao 928
# Fitness= 5.507945739999867
# 20
# 20
# geracao 929
# Fitness= 5.507945739999867
# 20
# 20
# geracao 930
# Fitness= 5.507945739999867
# 20
# 20
# geracao 931
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 932
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 933
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 934
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 935
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 936
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 937
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 938
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 939
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 940
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 941
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 942
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 943
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 944
# Fitness= 5.5075707156658265
# 20
# 20
# geracao 945
# Fitness= 5.496527328473292
# 20
# 20
# geracao 946
# Fitness= 5.496527328473292
# 20
# 20
# geracao 947
# Fitness= 5.496527328473292
# 20
# 20
# geracao 948
# Fitness= 5.496527328473292
# 20
# 20
# geracao 949
# Fitness= 5.496527328473292
# 20
# 20
# geracao 950
# Fitness= 5.496527328473292
# 20
# 20
# geracao 951
# Fitness= 5.496527328473292
# 20
# 20
# geracao 952
# Fitness= 5.496527328473292
# 20
# 20
# geracao 953
# Fitness= 5.496527328473292
# 20
# 20
# geracao 954
# Fitness= 5.496527328473292
# 20
# 20
# geracao 955
# Fitness= 5.493062825088733
# 20
# 20
# geracao 956
# Fitness= 5.493062825088733
# 20
# 20
# geracao 957
# Fitness= 5.493062825088733
# 20
# 20
# geracao 958
# Fitness= 5.493062825088733
# 20
# 20
# geracao 959
# Fitness= 5.493062825088733
# 20
# 20
# geracao 960
# Fitness= 5.493062825088733
# 20
# 20
# geracao 961
# Fitness= 5.493062825088733
# 20
# 20
# geracao 962
# Fitness= 5.493062825088733
# 20
# 20
# geracao 963
# Fitness= 5.493062825088733
# 20
# 20
# geracao 964
# Fitness= 5.493062825088733
# 20
# 20
# geracao 965
# Fitness= 5.493062825088733
# 20
# 20
# geracao 966
# Fitness= 5.493062825088733
# 20
# 20
# geracao 967
# Fitness= 5.493062825088733
# 20
# 20
# geracao 968
# Fitness= 5.493062825088733
# 20
# 20
# geracao 969
# Fitness= 5.493062825088733
# 20
# 20
# geracao 970
# Fitness= 5.493062825088733
# 20
# 20
# geracao 971
# Fitness= 5.493062825088733
# 20
# 20
# geracao 972
# Fitness= 5.493062825088733
# 20
# 20
# geracao 973
# Fitness= 5.493062825088733
# 20
# 20
# geracao 974
# Fitness= 5.493062825088733
# 20
# 20
# geracao 975
# Fitness= 5.493062825088733
# 20
# 20
# geracao 976
# Fitness= 5.493062825088733
# 20
# 20
# geracao 977
# Fitness= 5.493062825088733
# 20
# 20
# geracao 978
# Fitness= 5.493062825088733
# 20
# 20
# geracao 979
# Fitness= 5.493062825088733
# 20
# 20
# geracao 980
# Fitness= 5.493062825088733
# 20
# 20
# geracao 981
# Fitness= 5.493062825088733
# 20
# 20
# geracao 982
# Fitness= 5.477045986414314
# 20
# 20
# geracao 983
# Fitness= 5.477045986414314
# 20
# 20
# geracao 984
# Fitness= 5.477045986414314
# 20
# 20
# geracao 985
# Fitness= 5.477045986414314
# 20
# 20
# geracao 986
# Fitness= 5.477045986414314
# 20
# 20
# geracao 987
# Fitness= 5.477045986414314
# 20
# 20
# geracao 988
# Fitness= 5.477045986414314
# 20
# 20
# geracao 989
# Fitness= 5.477045986414314
# 20
# 20
# geracao 990
# Fitness= 5.470810957831404
# 20
# 20
# geracao 991
# Fitness= 5.470810957831404
# 20
# 20
# geracao 992
# Fitness= 5.470810957831404
# 20
# 20
# geracao 993
# Fitness= 5.470810957831404
# 20
# 20
# geracao 994
# Fitness= 5.470810957831404
# 20
# 20
# geracao 995
# Fitness= 5.470810957831404
# 20
# 20
# geracao 996
# Fitness= 5.470810957831404
# 20
# 20
# geracao 997
# Fitness= 5.470810957831404
# 20
# 20
# geracao 998
# Fitness= 5.470810957831404
# 20
# 20
# geracao 999
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1000
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1001
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1002
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1003
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1004
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1005
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1006
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1007
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1008
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1009
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1010
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1011
# Fitness= 5.470810957831404
# 20
# 20
# geracao 1012
# Fitness= 5.458776494227024
# 20
# 20
# geracao 1013
# Fitness= 5.458776494227024
# 20
# 20
# geracao 1014
# Fitness= 5.458776494227024
# 20
# 20
# geracao 1015
# Fitness= 5.458776494227024
# 20
# 20
# geracao 1016
# Fitness= 5.458776494227024
# 20
# 20
# geracao 1017
# Fitness= 5.373527127410072
# 20
# 20
# geracao 1018
# Fitness= 5.373527127410072
# 20
# 20
# geracao 1019
# Fitness= 5.368951188621322
# 20
# 20
# geracao 1020
# Fitness= 5.368951188621322
# 20
# 20
# geracao 1021
# Fitness= 5.358248805233569
# 20
# 20
# geracao 1022
# Fitness= 5.358248805233569
# 20
# 20
# geracao 1023
# Fitness= 5.355525216820359
# 20
# 20
# geracao 1024
# Fitness= 5.186634610641044
# 20
# 20
# geracao 1025
# Fitness= 5.172536413561706
# 20
# 20
# geracao 1026
# Fitness= 5.172536413561706
# 20
# 20
# geracao 1027
# Fitness= 5.172536413561706
# 20
# 20
# geracao 1028
# Fitness= 5.172536413561706
# 20
# 20
# geracao 1029
# Fitness= 5.172536413561706
# 20
# 20
# geracao 1030
# Fitness= 5.172536413561706
# 20
# 20
# geracao 1031
# Fitness= 5.172536413561706
# 20
# 20
# geracao 1032
# Fitness= 5.172536413561706
# 20
# 20
# geracao 1033
# Fitness= 5.169462296267706
# 20
# 20
# geracao 1034
# Fitness= 5.169462296267706
# 20
# 20
# geracao 1035
# Fitness= 5.169462296267706
# 20
# 20
# geracao 1036
# Fitness= 5.169462296267706
# 20
# 20
# geracao 1037
# Fitness= 5.169462296267706
# 20
# 20
# geracao 1038
# Fitness= 5.169462296267706
# 20
# 20
# geracao 1039
# Fitness= 5.166304408872325
# 20
# 20
# geracao 1040
# Fitness= 5.163237723412065
# 20
# 20
# geracao 1041
# Fitness= 5.163237723412065
# 20
# 20
# geracao 1042
# Fitness= 5.163237723412065
# 20
# 20
# geracao 1043
# Fitness= 5.163237723412065
# 20
# 20
# geracao 1044
# Fitness= 5.163237723412065
# 20
# 20
# geracao 1045
# Fitness= 5.163237723412065
# 20
# 20
# geracao 1046
# Fitness= 5.163237723412065
# 20
# 20
# geracao 1047
# Fitness= 5.163237723412065
# 20
# 20
# geracao 1048
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1049
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1050
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1051
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1052
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1053
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1054
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1055
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1056
# Fitness= 5.162523057574161
# 20
# 20
# geracao 1057
# Fitness= 5.136019066685395
# 20
# 20
# geracao 1058
# Fitness= 5.136019066685395
# 20
# 20
# geracao 1059
# Fitness= 5.136019066685395
# 20
# 20
# geracao 1060
# Fitness= 5.136019066685395
# 20
# 20
# geracao 1061
# Fitness= 5.136019066685395
# 20
# 20
# geracao 1062
# Fitness= 5.136019066685395
# 20
# 20
# geracao 1063
# Fitness= 5.136019066685395
# 20
# 20
# geracao 1064
# Fitness= 5.136019066685395
# ...
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1660
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1661
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1662
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1663
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1664
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1665
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1666
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1667
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1668
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1669
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1670
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1671
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1672
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1673
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1674
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1675
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1676
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1677
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1678
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1679
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1680
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1681
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1682
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1683
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1684
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1685
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1686
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1687
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1688
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1689
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1690
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1691
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1692
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1693
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1694
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1695
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1696
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1697
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1698
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1699
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1700
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1701
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1702
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1703
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1704
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1705
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1706
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1707
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1708
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1709
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1710
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1711
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1712
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1713
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1714
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1715
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1716
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1717
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1718
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1719
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1720
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1721
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1722
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1723
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1724
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1725
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1726
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1727
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1728
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1729
# Fitness= 3.5829133216709637
# 20
# 20
# geracao 1730
# Fitness= 3.545470592572336
# 20
# 20
# geracao 1731
# Fitness= 3.545470592572336
# 20
# 20
# geracao 1732
# Fitness= 3.545470592572336
# 20
# 20
# geracao 1733
# Fitness= 3.545470592572336
# 20
# 20
# geracao 1734
# Fitness= 3.484767504473461
# 20
# 20
# geracao 1735
# Fitness= 3.484767504473461
# 20
# 20
# geracao 1736
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1737
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1738
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1739
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1740
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1741
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1742
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1743
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1744
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1745
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1746
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1747
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1748
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1749
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1750
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1751
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1752
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1753
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1754
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1755
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1756
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1757
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1758
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1759
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1760
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1761
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1762
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1763
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1764
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1765
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1766
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1767
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1768
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1769
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1770
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1771
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1772
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1773
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1774
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1775
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1776
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1777
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1778
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1779
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1780
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1781
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1782
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1783
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1784
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1785
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1786
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1787
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1788
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1789
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1790
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1791
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1792
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1793
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1794
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1795
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1796
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1797
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1798
# Fitness= 3.4755012233361264
# 20
# 20
# geracao 1799
# Fitness= 3.458064202968714
# 20
# 20
# geracao 1800
# Fitness= 3.458064202968714
# 20
# 20
# geracao 1801
# Fitness= 3.458064202968714
# 20
# 20
# geracao 1802
# Fitness= 3.458064202968714
# 20
# 20
# geracao 1803
# Fitness= 3.458064202968714
# 20
# 20
# geracao 1804
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1805
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1806
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1807
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1808
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1809
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1810
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1811
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1812
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1813
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1814
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1815
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1816
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1817
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1818
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1819
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1820
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1821
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1822
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1823
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1824
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1825
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1826
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1827
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1828
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1829
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1830
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1831
# Fitness= 3.4567927642227287
# 20
# 20
# geracao 1832
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1833
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1834
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1835
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1836
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1837
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1838
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1839
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1840
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1841
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1842
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1843
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1844
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1845
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1846
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1847
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1848
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1849
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1850
# Fitness= 3.449919378449026
# 20
# 20
# geracao 1851
# Fitness= 3.406313597391212
# 20
# 20
# geracao 1852
# Fitness= 3.406313597391212
# 20
# 20
# geracao 1853
# Fitness= 3.406313597391212
# 20
# 20
# geracao 1854
# Fitness= 3.406313597391212
# 20
# 20
# geracao 1855
# Fitness= 3.406313597391212
# 20
# 20
# geracao 1856
# Fitness= 3.406313597391212
# 20
# 20
# geracao 1857
# Fitness= 3.406313597391212
# 20
# 20
# geracao 1858
# Fitness= 3.3937449324224658
# 20
# 20
# geracao 1859
# Fitness= 3.3937449324224658
# 20
# 20
# geracao 1860
# Fitness= 3.3937449324224658
# 20
# 20
# geracao 1861
# Fitness= 3.3937449324224658
# 20
# 20
# geracao 1862
# Fitness= 3.3937449324224658
# 20
# 20
# geracao 1863
# Fitness= 3.3937449324224658
# 20
# 20
# geracao 1864
# Fitness= 3.3937449324224658
# 20
# 20
# geracao 1865
# Fitness= 3.3937449324224658
# 20
# 20
# geracao 1866
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1867
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1868
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1869
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1870
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1871
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1872
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1873
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1874
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1875
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1876
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1877
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1878
# Fitness= 3.2426311727251713
# 20
# 20
# geracao 1879
# Fitness= 3.2316568563204733
# 20
# 20
# geracao 1880
# Fitness= 3.2316568563204733
# 20
# 20
# geracao 1881
# Fitness= 3.2316568563204733
# 20
# 20
# geracao 1882
# Fitness= 3.2316568563204733
# 20
# 20
# geracao 1883
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1884
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1885
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1886
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1887
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1888
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1889
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1890
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1891
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1892
# Fitness= 3.2111884259782983
# 20
# 20
# geracao 1893
# Fitness= 3.210257090191111
# 20
# 20
# geracao 1894
# Fitness= 3.210257090191111
# 20
# 20
# geracao 1895
# Fitness= 3.210257090191111
# 20
# 20
# geracao 1896
# Fitness= 3.208134561660322
# 20
# 20
# geracao 1897
# Fitness= 3.208134561660322
# 20
# 20
# geracao 1898
# Fitness= 3.208134561660322
# 20
# 20
# geracao 1899
# Fitness= 3.208134561660322
# 20
# 20
# geracao 1900
# Fitness= 3.208134561660322
# 20
# 20
# geracao 1901
# Fitness= 3.208134561660322
# 20
# 20
# geracao 1902
# Fitness= 3.208134561660322
# 20
# 20
# geracao 1903
# Fitness= 3.208134561660322
# 20
# 20
# geracao 1904
# Fitness= 3.1673656599257782
# 20
# 20
# geracao 1905
# Fitness= 3.1673656599257782
# 20
# 20
# geracao 1906
# Fitness= 3.1673656599257782
# 20
# 20
# geracao 1907
# Fitness= 3.1673656599257782
# 20
# 20
# geracao 1908
# Fitness= 3.1673656599257782
# 20
# 20
# geracao 1909
# Fitness= 3.1673656599257782
# 20
# 20
# geracao 1910
# Fitness= 3.1673656599257782
# 20
# 20
# geracao 1911
# Fitness= 3.1673656599257782
# 20
# 20
# geracao 1912
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1913
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1914
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1915
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1916
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1917
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1918
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1919
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1920
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1921
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1922
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1923
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1924
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1925
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1926
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1927
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1928
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1929
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1930
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1931
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1932
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1933
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1934
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1935
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1936
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1937
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1938
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1939
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1940
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1941
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1942
# Fitness= 3.1557295590389893
# 20
# 20
# geracao 1943
# Fitness= 3.1473909893237635
# 20
# 20
# geracao 1944
# Fitness= 3.1473909893237635
# 20
# 20
# geracao 1945
# Fitness= 3.1473909893237635
# 20
# 20
# geracao 1946
# Fitness= 3.1473909893237635
# 20
# 20
# geracao 1947
# Fitness= 3.1473909893237635
# 20
# 20
# geracao 1948
# Fitness= 3.1473909893237635
# 20
# 20
# geracao 1949
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1950
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1951
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1952
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1953
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1954
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1955
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1956
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1957
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1958
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1959
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1960
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1961
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1962
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1963
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1964
# Fitness= 3.1012688832083803
# 20
# 20
# geracao 1965
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1966
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1967
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1968
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1969
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1970
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1971
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1972
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1973
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1974
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1975
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1976
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1977
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1978
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1979
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1980
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1981
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1982
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1983
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1984
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1985
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1986
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1987
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1988
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1989
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1990
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1991
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1992
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1993
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1994
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1995
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1996
# Fitness= 3.030157801179598
# 20
# 20
# geracao 1997
# Fitness= 3.0269522446548414
# 20
# 20
# geracao 1998
# Fitness= 3.0269522446548414
# 20
# 20
# geracao 1999
# Fitness= 3.0269522446548414
# Tempo do algoritmo genético: 409.16924142837524
# 3.0269522446548414

# %%
melhores_ind = top.ind_better

# %%
frist_ind = melhores_ind[0]
mid_ind = melhores_ind[1000]
last_ind = melhores_ind[1999]
print(last_ind)
print(mid_ind)
print(frist_ind)
# Out:
# [[ 1.10670592e+03 -4.86170759e+03  1.29555810e+03]
#  [-6.43889701e+02 -1.18930684e+03  1.48064646e+03]
#  [-2.65852270e+03  3.11349005e+03  5.06518376e+03]
#  [-8.36799235e+02  3.56899062e+02  4.56039200e+03]
#  [-4.29634369e+02 -3.33954409e+02  1.82991574e+03]
#  [-1.31200032e+02 -1.62668039e+03  1.49864847e+03]
#  [-6.71396097e+02  7.02521478e+02  1.96079650e+03]
#  [-3.28384095e+02  1.29869142e+03  6.47910697e+02]
#  [-4.77546820e+01 -1.44211234e+03  6.39676936e+02]
#  [-4.46344717e+02  4.05041470e+02  1.01646625e+03]
#  [ 1.26960254e+02 -8.07982444e+02  1.82389868e+03]
#  [ 2.45728158e+03 -4.95230926e+03  2.10117792e+03]
#  [ 4.24083132e+03 -4.07449372e+03  1.77526428e+03]
#  [ 8.67561399e+02 -2.85301946e+03  1.01422246e+03]
#  [ 2.78048283e+01 -6.88877323e+02  2.69847388e+03]
#  [-3.70461264e+02  1.36272295e+02  1.13353812e+03]
#  [ 2.86401719e+02 -6.54653328e+01  1.19516499e+03]
#  [ 5.17706428e+02 -5.91289958e+02  1.12149692e+03]
#  [-4.21496685e+01  1.82174954e+03  8.44646317e+02]
#  [-6.74342099e+02  2.60391792e+03  7.85230566e+02]
#  [ 4.63005139e+00  2.80604488e+00  2.49825630e+00]]
# [[ 2.07076299e+03 -4.86170759e+03  1.47867794e+03]
#  [-6.43889701e+02  1.08381090e+02  2.33329675e+03]
#  [-3.87998214e+03  3.11349005e+03  5.07497626e+03]
#  [-8.36799235e+02  3.56899062e+02  1.06533383e+03]
#  [-4.29634369e+02 -1.09835003e+03  2.57375278e+03]
#  [ 4.12245857e+02 -1.62668039e+03  1.49864847e+03]
#  [-6.71396097e+02  4.63251819e+01  1.76215906e+03]
#  [-3.28384095e+02  1.29869142e+03  6.47910697e+02]
#  [-2.98294692e+02 -1.44211234e+03  6.39676936e+02]
#  [-4.46344717e+02  3.05523966e+03  1.79096903e+03]
#  [-1.09873978e+03 -8.07982444e+02  4.42795023e+03]
#  [ 2.45728158e+03 -4.95230926e+03  2.19822575e+03]
#  [ 3.55185372e+03 -4.07449372e+03  1.77526428e+03]
#  [ 8.67561399e+02 -2.85301946e+03  1.01422246e+03]
#  [-2.73812497e+03  4.27348807e+03  2.69847388e+03]
#  [-3.70461264e+02  1.36272295e+02  1.33960780e+03]
#  [-5.18754251e+02 -3.91036519e+02  1.88850889e+03]
#  [-5.60705443e+02  1.36556234e+02  1.12149692e+03]
#  [-4.21496685e+01  1.11096986e+03  8.44646317e+02]
#  [-6.74342099e+02  2.60391792e+03  7.85230566e+02]
#  [ 4.96884577e+00  2.56295535e+00  2.49508170e+00]]
# [[ 6.84563457e+02  2.82415996e+03  4.76958446e+03]
#  [-4.71287794e+03 -4.23925200e+03  3.80091490e+03]
#  [-1.53405804e+03  4.23718175e+03  2.00448437e+03]
#  [-1.17372713e+03  1.63390663e+03  6.23317532e+03]
#  [-1.51357654e+03  1.66497430e+03  2.84818886e+03]
#  [-3.22202678e+03  2.55543309e+03  1.49864847e+03]
#  [-4.41042704e+03  3.08594170e+03  8.35140465e+02]
#  [-8.17260624e+02 -3.92400094e+02  2.19656143e+03]
#  [ 3.19421911e+03 -1.44211234e+03  2.69867604e+03]
#  [-3.83755179e+03 -6.96344939e+02  2.49092814e+03]
#  [-1.83458380e+03  2.30857061e+03  6.13193868e+03]
#  [ 3.76753997e+03  3.44419544e+03  6.23906873e+03]
#  [-2.42920856e+03 -4.16280903e+03  1.77526428e+03]
#  [ 8.67561399e+02  4.51804552e+03  5.53623091e+03]
#  [ 4.66907920e+03  4.57370623e+03  4.62827453e+03]
#  [-4.04718104e+03 -2.02151537e+03  1.91332172e+03]
#  [-5.18754251e+02 -6.72153673e+02  1.93784869e+03]
#  [-5.60705443e+02 -2.40816422e+03  1.12149692e+03]
#  [ 1.81198100e+03 -1.99371381e+03  1.99856214e+03]
#  [-6.74342099e+02  1.10093113e+03  7.85230566e+02]
#  [ 1.47904495e+00 -3.30394924e+00  2.14419433e+00]]

# %%
def divide_param_dipolo(pop):
    coodX1 = []
    coodY1 = []
    coodZ1 = []
    incl1 = []
    decl1 = []
    mag1 = []

    for i in range(len(pop)-1):
        coodX1.append(pop[i][0])
        coodY1.append(pop[i][1])
        coodZ1.append(pop[i][2])
        incl1.append(pop[len(pop)-1][0])
        decl1.append(pop[len(pop)-1][1])
        mag1.append(pop[len(pop)-1][2])
    return coodX1, coodY1, coodZ1, incl1, decl1, mag1

# %%
coodX1, coodY1, coodZ1, incl1, decl1, mag1 = divide_param_dipolo(frist_ind)
coodX2, coodY2, coodZ2, incl2, decl2, mag2 = divide_param_dipolo(mid_ind)
coodX3, coodY3, coodZ3, incl3, decl3, mag3 = divide_param_dipolo(last_ind)

# %% [markdown]
# ## Plot's

# %%
view = [190, 130]
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
#plano = ax.contourf(Yref, Xref, tfa_n_bolinhas, offset=0, cmap=plt.cm.RdBu_r)
individuo0 = ax.scatter(coodX1, coodY1, coodZ1, c=incl1, depthshade=True, cmap='jet', s = 200.0)
plt.xlim(-5000, 5000)
plt.ylim(-5000, 5000)
#plt.zlim(0, 7000)
plt.title('Primeiro Indivíduo', fontsize=20)
ax.set_xlabel('East (m)', fontsize=20)
ax.set_ylabel('North (m)', fontsize=20)
ax.set_zlabel('Depth (m)', fontsize=20)
plt.colorbar(individuo0, shrink=0.65)
plt.grid()
ax.view_init(view[0], view[1])
plt.show()

# %%
view = [190, 130]
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
#plano = ax.contourf(Yref, Xref, tfa_n_bolinhas, offset=0, cmap=plt.cm.RdBu_r)
individuo1 = ax.scatter(coodX2, coodY2, coodZ2, c=incl2, depthshade=True, cmap='jet', s = 200.0)
plt.xlim(-5000, 5000)
plt.ylim(-5000, 5000)
plt.title('Mid Indivíduo', fontsize=20)
ax.set_xlabel('East (m)', fontsize=20)
ax.set_ylabel('North (m)', fontsize=20)
ax.set_zlabel('Depth (m)', fontsize=20)
plt.colorbar(individuo1, shrink=0.65)
plt.grid()
ax.view_init(view[0], view[1])
plt.show()

# %%
view = [190, 130]
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
#plano = ax.contourf(Yref, Xref, tfa_n_bolinhas, offset=0, cmap=plt.cm.RdBu_r)
individuo3 = ax.scatter(coodX3, coodY3, coodZ3, c=incl3, depthshade=True, cmap='jet', s = 200.0)
plt.xlim(-5000, 5000)
plt.ylim(-5000, 5000)
plt.title('Final Indivíduo', fontsize=20)
ax.set_xlabel('East (m)', fontsize=20)
ax.set_ylabel('North (m)', fontsize=20)
ax.set_zlabel('Depth (m)', fontsize=20)
plt.colorbar(individuo0, shrink=0.65)
plt.grid()
ax.view_init(view[0], view[1])
plt.show()

# %%
fit_rodada = top.val_fit

# %%
x = np.linspace(0, 2000, 2000)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, fit_rodada)
plt.ylim(0, max(fit_rodada))
plt.xlabel('Número de Gerações', fontsize=20)
plt.ylabel('fitness', fontsize=20)
plt.grid()
plt.show()

# %%
x = top.x
y = top.y

# %%
# coordenadas dos vertices (corners) do prisma, em metros:
x1,x2  = (-500.0, 500.0) 
y1,y2  = (-2500.0, 2500.0)
z1,z2  = (200.0, 3000.0)   # z eh positivo para baixo!
deltaz = 0.0
deltay = 0.0
incl = 'positivo'


dic = {'n': 1,
       'x': [x1, x2],
       'y': [y1, y2],
       'z': [z1, z2],
       'deltay': deltay,
       'deltaz': deltaz,
       'incl': 'positivo'}

pointx, pointy, pointz = plot_3D.creat_point(**dic)

dic1 = {'x': [pointx[0], pointx[1]],
        'y': [pointy[0], pointy[1]],
        'z': [pointz[0], pointz[1]]}

vert1 =  plot_3D.vert_point(dic1)

color = 'b'
size = [9, 10]
view = [210,145]

prism_1 = plot_3D.plot_prism(vert1, color)

prism = {'n': 1,
         'prisma': [prism_1]}#, prism_2,prism_3]}

plot_3D.plot_obs_3d(prism, size, view, x, y, pointz)

# %%
"""figure = plt.figure(figsize=(size[0],size[1]))
ax = figure.gca(projection = '3d')
    #----------------------------------------------------------------------------------------------------#
n = prism.get('n')
prisma = prism.get('prisma')

ax.add_collection3d(prism_1)
#----------------------------------------------------------------------------------------------------#
# Define the scale of the projection
x_scale = 1.2
y_scale = 1.2
z_scale = 1.
scale=np.diag([x_scale, y_scale, z_scale, 1.0])
scale=scale*(1.0/scale.max())
scale[3,3] = 1.

    # Labels
ax.set_xlabel('North (m)', size = 25, labelpad = 30)
ax.set_ylabel('East (m)', size = 25, labelpad = 30)
ax.set_zlabel('Depth (m)', size = 25, labelpad = 30)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(y.min(), y.max())
ax.set_zlim(min(pointz)-500.0, max(pointz)+500.0)
    #ax.set_xticks(numpy.arange(x.min(), x.max(), 2500))
    #ax.set_yticks(numpy.linspace(y.min(), y.max(), 5))
    #ax.set_zticks(numpy.linspace(0., z[1], 6))
    #ax.tick_params(labelsize = 20, pad = 10)

    # Visualization angle
ax.view_init(view[0], view[1])

plt.tight_layout(True)
    #plt.savefig('prisma_3D.pdf', format='pdf')

plt.show()
"""
# Out:
# "figure = plt.figure(figsize=(size[0],size[1]))\nax = figure.gca(projection = '3d')\n    #----------------------------------------------------------------------------------------------------#\nn = prism.get('n')\nprisma = prism.get('prisma')\n\nax.add_collection3d(prism_1)\n#----------------------------------------------------------------------------------------------------#\n# Define the scale of the projection\nx_scale = 1.2\ny_scale = 1.2\nz_scale = 1.\nscale=np.diag([x_scale, y_scale, z_scale, 1.0])\nscale=scale*(1.0/scale.max())\nscale[3,3] = 1.\n\n    # Labels\nax.set_xlabel('North (m)', size = 25, labelpad = 30)\nax.set_ylabel('East (m)', size = 25, labelpad = 30)\nax.set_zlabel('Depth (m)', size = 25, labelpad = 30)\nax.set_xlim(x.min(), x.max())\nax.set_ylim(y.min(), y.max())\nax.set_zlim(min(pointz)-500.0, max(pointz)+500.0)\n    #ax.set_xticks(numpy.arange(x.min(), x.max(), 2500))\n    #ax.set_yticks(numpy.linspace(y.min(), y.max(), 5))\n    #ax.set_zticks(numpy.linspace(0., z[1], 6))\n    #ax.tick_params(labelsize = 20, pad = 10)\n\n    # Visualization angle\nax.view_init(view[0], view[1])\n\nplt.tight_layout(True)\n    #plt.savefig('prisma_3D.pdf', format='pdf')\n\nplt.show()\n"

# %%
Y = top.Y
X = top.X
anomaly_cubo = top.anomaly_cubo
anomaly_better = top.anomaly_better
final_anomaly = anomaly_better[999]

# %%
inc = 0.0 # magnetizacao puramente induzida
dec = 0.0 
Mi  = 2.0 # intensidade da magnetizacao em A/m
I = top.I
D = top.D
inc_ball, decl_ball = last_ind[6][0], last_ind[6][1]

rptx, rpty, rptz = auxiliars.dircos(inc, dec)# Vetor Magnetização do corpo

ptx, pty, ptz = auxiliars.dircos(I, D)# Vetor de magnetização Regional

bptx, bpty, bptz = auxiliars.dircos(inc_ball, decl_ball)# Vetor de magnetização estimada

print(rptx, rpty, rptz)
print(ptx, pty, ptz)
print(bptx, bpty, bptz)
# Out:
# 1.0 0.0 0.0
# 0.3407186534216102 0.9361168066628591 0.08715574274765817
# 0.6307300928798584 -0.1986085182426332 0.7501561213622341

# %%
plt.figure(figsize=(9,10))
bolas = plt.contourf(Y, X, final_anomaly, 10, cmap = plt.cm.RdBu_r)
#plt.clabel(bolas , inline=2, fontsize=12, colors = 'k')
#cubo = plt.contourf(Y, X, anomaly_cubo, 10, cmap = plt.cm.RdBu_r)
plt.title('Anomalia de Campo Total do Indivíduo final(nT)', fontsize = 20)
plt.xlabel('East (m)', fontsize = 20)
plt.ylabel('North (m)', fontsize = 20)
plt.colorbar()
#plt.savefig('prisma_anomalia.pdf', format='pdf')
plt.show()

# %%
max_cubo = np.max(anomaly_cubo)
print(max_cubo)
min_cubo = np.min(anomaly_cubo)
print(min_cubo)
# Out:
# 163.61441304441934
# -251.84033395348115

# %%
plt.figure(figsize=(9,10))
bolas = plt.contour(Y, X, final_anomaly, levels = 10, cmap = plt.cm.RdBu_r, linewidths = 2, vmin = np.min(anomaly_cubo), vmax = np.max(anomaly_cubo))
plt.clabel(bolas , inline=2, fontsize=12, colors = 'k')
cubo = plt.contourf(Y, X, anomaly_cubo, 10, cmap = plt.cm.RdBu_r, vmin = np.min(anomaly_cubo), vmax = np.max(anomaly_cubo))
arrow = plt.arrow(0.0, 0.0, 1000.0*ptx, 1000.0*pty, width=50.0,head_width=250.0, length_includes_head = False, color = 'k')
arrow1 = plt.arrow(0.0, 0.0, 1000.0*rptx, 1000.0*rpty, width=50.0,head_width=250.0, length_includes_head = False, color = 'g')
arrow2 = plt.arrow(0.0, 0.0, 1000.0*bptx, 1000.0*bpty, width=50.0,head_width=250.0, length_includes_head = False, color = 'y')
#first_legend = plt.legend(handles=[cubo], bbox_to_anchor=(1.25, 1), loc='upper left', borderaxespad=0.0, fontsize= 12.0)
#plt.legend([arrow, arrow1, arrow2], ['Vetor magnetização da fonte', 'Vetor magnetização do campo Regional', 'Vetor de magnetização do Campo estimado'], bbox_to_anchor=(1.2, 1), loc='upper left', borderaxespad=0.0, fontsize= 12.0)
plt.title('Anomalia de Campo Total do Indivíduo final(nT)', fontsize = 20)
plt.xlabel('East (m)', fontsize = 20)
plt.ylabel('North (m)', fontsize = 20)
plt.colorbar()
#plt.savefig('prisma_anomalia.pdf', format='pdf')
plt.show()

# %%
residuo_anomaly = anomaly_cubo - final_anomaly
res = np.reshape(residuo_anomaly, (400))
#print(res)

res_mu = np.mean(res)
res_sigma = np.std(res)

# %%
from scipy.stats import norm

# %%
plt.figure(figsize=(8,8))
s = (res - res_mu) / res_sigma
s = np.ravel(s)
nbins = int(np.max(s) - np.min(s))
n, bins, patches = plt.hist(s, 50, facecolor = 'blue', alpha = 1.)
y_hist = norm.pdf(bins, np.mean(s), np.std(s))
plt.plot(bins, 70*y_hist, 'k--', linewidth = 2)
plt.text(6,50, '$\mu$=%0.5f' % (res_mu), horizontalalignment = 'center', fontsize = 12)
plt.text(6,55, '$\sigma$=%0.5f' % (res_sigma), horizontalalignment = 'center', fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(9,10))
bolas = plt.contourf(Y, X, residuo_anomaly, 10, cmap = plt.cm.RdBu_r)
#plt.clabel(bolas , inline=2, fontsize=12, colors = 'k')
#cubo = plt.contourf(Y, X, anomaly_cubo, 10, cmap = plt.cm.RdBu_r)
plt.title('Residuo da Anomalia de Campo Total do Indivíduo final(nT)', fontsize = 20)
plt.xlabel('East (m)', fontsize = 20)
plt.ylabel('North (m)', fontsize = 20)
plt.colorbar()
#plt.savefig('prisma_anomalia.pdf', format='pdf')
plt.show()

# %%
# Plot the main 3D source
figure = plt.figure(figsize=(10,10))

ax = figure.gca(projection = '3d')
#ax.set_title('Vertical dike model', size = 18)

#x1, x2, y1, y2, z1, z2 = fonte_crustal_mag[:6]
v = np.array([[x1, y1, z2], [x1, y2, z2], [x2, y2, z2], [x2, y1, z2], 
                 [x1, y1, z1], [x1, y2, z1], [x2, y2, z1], [x2, y1, z1]])
vert =  [[v[0],v[1],v[2],v[3]], 
         [v[0],v[1],v[5],v[4]], 
         [v[1],v[2],v[6],v[5]],
         [v[2],v[3],v[7],v[6]], 
         [v[3],v[0],v[4],v[7]], 
         [v[4],v[5],v[6],v[7]]]

fig01 = Poly3DCollection(vert, alpha = 0.75, linewidths = 0.75, edgecolors = 'k')
fig01.set_facecolor('chocolate')
ax.add_collection3d(fig01)
individuo0 = ax.scatter(coodX1, coodY1, coodZ1, c=incl1, depthshade=True, cmap='jet', s = 200.0)

# Define the scale of the projection
x_scale = 1.2
y_scale = 1.2
z_scale = 1.
scale=np.diag([x_scale, y_scale, z_scale, 1.0])
scale=scale*(1.0/scale.max())
scale[3,3] = 1.
def short_proj():
    return np.dot(Axes3D.get_proj(ax), scale)
ax.get_proj = short_proj

# Labels
ax.set_xlabel('North (m)', size = 25, labelpad = 30)
ax.set_ylabel('East (m)', size = 25, labelpad = 30)
ax.set_zlabel('Depth (m)', size = 25, labelpad = 30)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(y.min(), y.max())
ax.set_zlim(0., 7000)
ax.set_xticks(np.arange(x.min(), x.max(), 2500))
ax.set_yticks(np.linspace(y.min(), y.max(), 5))
ax.set_zticks(np.linspace(0., 7000, 6))
ax.tick_params(labelsize = 20, pad = 10)

# Visualization angle
ax.view_init(190, 130)

plt.tight_layout(True)
#plt.savefig('figs/dikemodel-r1.png', dpi = 300, bbox_inches = 'tight', transparent = True)
#plt.savefig('figs/dikemodel-r1.pdf', dpi = 300, bbox_inches = 'tight', transparent = True)
plt.show()

# %%
# Plot the main 3D source
figure = plt.figure(figsize=(10,10))

ax = figure.gca(projection = '3d')
#ax.set_title('Vertical dike model', size = 18)

#x1, x2, y1, y2, z1, z2 = fonte_crustal_mag[:6]
v = np.array([[x1, y1, z2], [x1, y2, z2], [x2, y2, z2], [x2, y1, z2], 
                 [x1, y1, z1], [x1, y2, z1], [x2, y2, z1], [x2, y1, z1]])
vert =  [[v[0],v[1],v[2],v[3]], 
         [v[0],v[1],v[5],v[4]], 
         [v[1],v[2],v[6],v[5]],
         [v[2],v[3],v[7],v[6]], 
         [v[3],v[0],v[4],v[7]], 
         [v[4],v[5],v[6],v[7]]]

fig01 = Poly3DCollection(vert, alpha = 0.75, linewidths = 0.75, edgecolors = 'k')
fig01.set_facecolor('chocolate')
ax.add_collection3d(fig01)
individuo0 = ax.scatter(coodX2, coodY2, coodZ2, c=incl2, depthshade=True, cmap='jet', s = 200.0)

# Define the scale of the projection
x_scale = 1.2
y_scale = 1.2
z_scale = 1.
scale=np.diag([x_scale, y_scale, z_scale, 1.0])
scale=scale*(1.0/scale.max())
scale[3,3] = 1.
def short_proj():
    return np.dot(Axes3D.get_proj(ax), scale)
ax.get_proj = short_proj

# Labels
ax.set_xlabel('North (m)', size = 25, labelpad = 30)
ax.set_ylabel('East (m)', size = 25, labelpad = 30)
ax.set_zlabel('Depth (m)', size = 25, labelpad = 30)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(y.min(), y.max())
ax.set_zlim(0., 7000)
ax.set_xticks(np.arange(x.min(), x.max(), 2500))
ax.set_yticks(np.linspace(y.min(), y.max(), 5))
ax.set_zticks(np.linspace(0., 7000, 6))
ax.tick_params(labelsize = 20, pad = 10)

# Visualization angle
ax.view_init(190, 130)

plt.tight_layout(True)
#plt.savefig('figs/dikemodel-r1.png', dpi = 300, bbox_inches = 'tight', transparent = True)
#plt.savefig('figs/dikemodel-r1.pdf', dpi = 300, bbox_inches = 'tight', transparent = True)
plt.show()

# %%
#%matplotlib notebook
# Plot the main 3D source
figure = plt.figure(figsize=(10,10))

ax = figure.gca(projection = '3d')
#ax.set_title('Vertical dike model', size = 18)

#x1, x2, y1, y2, z1, z2 = fonte_crustal_mag[:6]
v = np.array([[x1, y1, z2], [x1, y2, z2], [x2, y2, z2], [x2, y1, z2], 
                 [x1, y1, z1], [x1, y2, z1], [x2, y2, z1], [x2, y1, z1]])
vert =  [[v[0],v[1],v[2],v[3]], 
         [v[0],v[1],v[5],v[4]], 
         [v[1],v[2],v[6],v[5]],
         [v[2],v[3],v[7],v[6]], 
         [v[3],v[0],v[4],v[7]], 
         [v[4],v[5],v[6],v[7]]]

fig01 = Poly3DCollection(vert, alpha = 0.35, linewidths = 0.75, edgecolors = 'k')
fig01.set_facecolor('chocolate')
ax.add_collection3d(fig01)
individuo0 = ax.scatter(coodX3, coodY3, coodZ3, c=incl3, depthshade=True, cmap='jet', s = 200.0)

# Define the scale of the projection
x_scale = 1.2
y_scale = 1.2
z_scale = 1.
scale=np.diag([x_scale, y_scale, z_scale, 1.0])
scale=scale*(1.0/scale.max())
scale[3,3] = 1.
def short_proj():
    return np.dot(Axes3D.get_proj(ax), scale)
ax.get_proj = short_proj

# Labels
ax.set_xlabel('North (m)', size = 25, labelpad = 30)
ax.set_ylabel('East (m)', size = 25, labelpad = 30)
ax.set_zlabel('Depth (m)', size = 25, labelpad = 30)
ax.set_xlim(x.min(), x.max())
ax.set_ylim(y.min(), y.max())
ax.set_zlim(0., 7000)
ax.set_xticks(np.arange(x.min(), x.max(), 2500))
ax.set_yticks(np.linspace(y.min(), y.max(), 5))
ax.set_zticks(np.linspace(0., 7000, 6))
ax.tick_params(labelsize = 20, pad = 10)

# Visualization angle
ax.view_init(190, 130)

plt.tight_layout(True)
#plt.savefig('figs/dikemodel-r1.png', dpi = 300, bbox_inches = 'tight', transparent = True)
#plt.savefig('figs/dikemodel-r1.pdf', dpi = 300, bbox_inches = 'tight', transparent = True)
plt.show()

# %%
pop_final = top.final_pop

# %%
print(pop_final)
# Out:
# [[array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.69155957e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.63005139e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.63005139e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.63005139e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.75583344e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.63005139e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.63005139e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.75583344e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00, -3.86869258e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.63005139e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.75583344e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.75583344e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  1.82374220e+00]]), array([[ 1.10670592e+03, -4.86170759e+03,  1.29555810e+03],
#        [-6.43889701e+02, -1.18930684e+03,  1.48064646e+03],
#        [-2.65852270e+03,  3.11349005e+03,  5.06518376e+03],
#        [-8.36799235e+02,  3.56899062e+02,  4.56039200e+03],
#        [-4.29634369e+02, -3.33954409e+02,  1.82991574e+03],
#        [-1.31200032e+02, -1.62668039e+03,  1.49864847e+03],
#        [-6.71396097e+02,  7.02521478e+02,  1.96079650e+03],
#        [-3.28384095e+02,  1.29869142e+03,  6.47910697e+02],
#        [-4.77546820e+01, -1.44211234e+03,  6.39676936e+02],
#        [-4.46344717e+02,  4.05041470e+02,  1.01646625e+03],
#        [ 1.26960254e+02, -8.07982444e+02,  1.82389868e+03],
#        [ 2.45728158e+03, -4.95230926e+03,  2.10117792e+03],
#        [ 4.24083132e+03, -4.07449372e+03,  1.77526428e+03],
#        [ 8.67561399e+02, -2.85301946e+03,  1.01422246e+03],
#        [ 2.78048283e+01, -6.88877323e+02,  2.69847388e+03],
#        [-3.70461264e+02,  1.36272295e+02,  1.13353812e+03],
#        [ 2.86401719e+02, -6.54653328e+01,  1.19516499e+03],
#        [ 5.17706428e+02, -5.91289958e+02,  1.12149692e+03],
#        [-4.21496685e+01,  1.82174954e+03,  8.44646317e+02],
#        [-6.74342099e+02,  2.60391792e+03,  7.85230566e+02],
#        [ 4.50271961e+00,  2.80604488e+00,  2.49825630e+00]])]]

# %%
from datetime import datetime

# %%
'''nx = 50 # n de observacoes na direcao x
ny = 50 # n de observacoes na direcao y
Z = top.Z
inc = 0.0 # magnetizacao puramente induzida
dec = 0.0 
Mi  = 2.0 # intensidade da magnetizacao em A/m
I = top.I
D = top.D

dici1 = {'nx': nx,
         'ny': ny,
         'X': X,
         'Y': Y,
         'Z': Z,
         'ACTn': pop_final
                  }

data_e_hora_atuais = datetime.now()
data_e_hora = data_e_hora_atuais.strftime('%d_%m_%Y_%H_%M')

dicionario = {'Data da Modelagem': data_e_hora,
              'Tipo de Modelagem': 'Modelagem de prisma',
              'números de corpos': 1,
              'Coordenadas do prisma 1 (x1, x2, y1, y2, z1, z2)': [pointx[0], pointx[1], pointy[0], pointy[1], pointz[0], pointz[1]],
              'inclinação': 'positivo',
              'Informação da fonte (Mag, Incl, Decl)': [Mi, inc, dec],
              'Informação regional (Camp.Geomag, Incl, Decl)': [I, D]}

print(dicionario)

Data_f = salve_doc.reshape_matrix(**dici1)'''
# Out:
# "nx = 50 # n de observacoes na direcao x\nny = 50 # n de observacoes na direcao y\nZ = top.Z\ninc = 0.0 # magnetizacao puramente induzida\ndec = 0.0 \nMi  = 2.0 # intensidade da magnetizacao em A/m\nI = top.I\nD = top.D\n\ndici1 = {'nx': nx,\n         'ny': ny,\n         'X': X,\n         'Y': Y,\n         'Z': Z,\n         'ACTn': pop_final\n                  }\n\ndata_e_hora_atuais = datetime.now()\ndata_e_hora = data_e_hora_atuais.strftime('%d_%m_%Y_%H_%M')\n\ndicionario = {'Data da Modelagem': data_e_hora,\n              'Tipo de Modelagem': 'Modelagem de prisma',\n              'números de corpos': 1,\n              'Coordenadas do prisma 1 (x1, x2, y1, y2, z1, z2)': [pointx[0], pointx[1], pointy[0], pointy[1], pointz[0], pointz[1]],\n              'inclinação': 'positivo',\n              'Informação da fonte (Mag, Incl, Decl)': [Mi, inc, dec],\n              'Informação regional (Camp.Geomag, Incl, Decl)': [I, D]}\n\nprint(dicionario)\n\nData_f = salve_doc.reshape_matrix(**dici1)"

# %%
'''df_pop_final = pd.DataFrame(pop_final)
#pasta = 'Logfile/27_10_2020_13_21'
#pop_final.to_csv(pasta)'''
# Out:
# "df_pop_final = pd.DataFrame(pop_final)\n#pasta = 'Logfile/27_10_2020_13_21'\n#pop_final.to_csv(pasta)"

# %%
'''df_pop_final'''
# Out:
# 'df_pop_final'

# %%
'''pasta = 'Logfile/27_10_2020_13_21/pop_final.csv'
df_pop_final.to_csv(pasta, index = False, header = False)'''
# Out:
# "pasta = 'Logfile/27_10_2020_13_21/pop_final.csv'\ndf_pop_final.to_csv(pasta, index = False, header = False)"

# %%
'''final_population = [[([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],
       [  186.10188459, -1745.49752541,   316.76113017],
       [  162.32668389, -1344.68304308,   291.76669771],
       [ -109.2860279 ,  1733.38549454,   166.56359794],
       [  231.86490014,  -827.87796208,  1317.81149003],
       [   -2.35366375,  1033.18283148,   229.14850516],
       [   -4.63820872,     9.33264247,     2.9651449 ]])]]'''
# Out:
# 'final_population = [[([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.63820872,     9.33264247,     2.9651449 ]]), ([[ -229.48475862,  1840.65751468,   231.8566945 ],\n       [  186.10188459, -1745.49752541,   316.76113017],\n       [  162.32668389, -1344.68304308,   291.76669771],\n       [ -109.2860279 ,  1733.38549454,   166.56359794],\n       [  231.86490014,  -827.87796208,  1317.81149003],\n       [   -2.35366375,  1033.18283148,   229.14850516],\n       [   -4.638 ...

# %%
#print(final_population)
