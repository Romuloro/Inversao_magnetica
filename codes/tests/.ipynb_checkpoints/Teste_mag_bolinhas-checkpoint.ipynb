# %%
# Import das Bibliotecas:
import numpy as np
import random
import sys
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection
from random import sample
import time
a = sys.path.append('../modules/') # endereco das funcoes implementadas por voce!
import plot_3D, auxiliars, salve_doc, sphere

# %%
data = pd.read_table('data.txt', sep =' ')

# %%
anomalyref = data['Total-Field Anomaly(nT)']
anomalyref = np.reshape(np.array(anomalyref), (100,100))

Xref = data['North(m)']
Xref = np.reshape(np.array(Xref), (100,100))

Yref = data['East(m)']
Yref = np.reshape(np.array(Yref), (100,100))

Zref = data['Elevation(m)']
Zref = np.reshape(np.array(Zref), (100,100))

# %%
#%matplotlib notebook
# graficos
plt.close('all')
plt.figure(figsize=(10,10))
#******************************************************
plt.contourf(Yref, Xref, anomalyref, 20, cmap = plt.cm.RdBu_r)
plt.title('Anomalia de Campo Total(nT)', fontsize = 12)
plt.xlabel('East (m)', fontsize = 10)
plt.ylabel('North (m)', fontsize = 10)
#corpo, = plt.plot(ys1,xs1,'k-*', label = 'Extensão do Dique')
#plt.plot(ys2,xs2,'k-')
#plt.plot(ys3,xs3,'m-')
#arrow = plt.arrow(2000.0, 0.0, 4500.0, 0.0, width=250, length_includes_head = True, color = 'k')
#first_legend = plt.legend(handles=[corpo], bbox_to_anchor=(1.25, 1), loc='upper left', borderaxespad=0.0, fontsize= 12.0)
#plt.legend([arrow, corpo], ['Direção de mergulho', 'Extensão do Dique'], bbox_to_anchor=(1.25, 1), loc='upper left', borderaxespad=0.0, fontsize= 12.0)
plt.colorbar()
#plt.savefig('teste_100_40000_D10.png', format='png')
plt.show()

# %%
inc = -20.0 #Inclinacao do campo do corpo em graus
dec = 10.0      # declinacao do campo do corpo em graus
Mi  = 11.0 # intensidade da magnetizacao em A/m


# Propriedades magneticas Refinal
I = -23.0 # inclinacao do campo principal em graus
D = 45.0  # declinacao do campo principal em graus

raio = 500.0 #RAIO FIXO AJUSTADO MANUALMENTE PELO USUÁRIO

# %%
x1,x2,x3,x4,x5 = (0.0, -10.0, -50.0, -100.0, -120.0) 
y1,y2,y3,y4,y5 = (-800.0, -1800.0, 200.0, 1100.0, 2000.0)
z1,z2,z3,z4,z5 = (870.0, 850.0, 850.0, 800.0, 750.0)

sphere1 = [x1,y1,z1,raio]
sphere2 = [x2,y2,z2,raio]
sphere3 = [x3,y3,z3,raio]
sphere4 = [x4,y4,z4,raio]
sphere5 = [x5,y5,z5,raio]

X = [x1,x2,x3,x4,x5]
Y = [y1,y2,y3,y4,y5]
Z = [z1,z2,z3,z4,z5]

print(type(sphere1))
# Out:
# <class 'list'>

# %%
#%matplotlib notebook
fig = plt.figure(figsize=(10,10))
#ax = fig.gca(projection='3d')
plt.scatter(Y, X, c=Z, cmap='rainbow')
plt.xlabel('East(m)')
plt.xlim(-5000, 5000)
plt.ylim(-5000, 5000)
plt.ylabel('North(m)')
plt.colorbar()

plt.grid()

plt.show()

# %%
tfa1 =sphere.sphere_tfa(Xref,Yref,Zref,sphere1,Mi,I,D,inc,dec)
tfa2 =sphere.sphere_tfa(Xref,Yref,Zref,sphere2,Mi,I,D,inc,dec)
tfa3 =sphere.sphere_tfa(Xref,Yref,Zref,sphere3,Mi,I,D,inc,dec)
tfa4 =sphere.sphere_tfa(Xref,Yref,Zref,sphere4,Mi,I,D,inc,dec)
tfa5 =sphere.sphere_tfa(Xref,Yref,Zref,sphere5,Mi,I,D,inc,dec)

tfa_f = tfa1 + tfa2 + tfa3 + tfa4 + tfa5

# %%
#"Função diferença"
def f_difference (dado_referencia, dado_calculado):
    std = np.std(dado_referencia)
    dif = (dado_referencia - dado_calculado)**2 / (std**2)
    rms = np.sum(dif) / len(dif)
    
    return rms

rms = f_difference(anomalyref, tfa_f)
print(rms)
# Out:
# 9.031424829934386

# %%
#%matplotlib inline
# graficos
plt.close('all')
plt.figure(figsize=(17,12))
#******************************************************
plt.subplot(1,2,1)
plt.contourf(Yref, Xref, tfa_f, 20, cmap = plt.cm.RdBu_r,
             vmin= data['Total-Field Anomaly(nT)'].min(),
             vmax=data['Total-Field Anomaly(nT)'].max())
plt.title('Anomalia de Campo Total Calculado(nT)', fontsize = 12)
plt.xlabel('East (m)', fontsize = 10)
plt.ylabel('North (m)', fontsize = 10)
plt.colorbar()
#******************************************************
plt.subplot(1,2,2)
plt.contourf(Yref, Xref, anomalyref, 20, cmap = plt.cm.RdBu_r,
            vmin= data['Total-Field Anomaly(nT)'].min(),
             vmax= data['Total-Field Anomaly(nT)'].max())
plt.title('Anomalia de Campo Total Observado(nT)', fontsize = 12)
plt.xlabel('East (m)', fontsize = 10)
plt.ylabel('North (m)', fontsize = 10)
plt.colorbar()

plt.show()

# %% [markdown]
# ## Função n bolinhas
# ### 1) As posições que serão escolhidas de forma aleatória, devem ser inseridas em formato de listas que não devem conter duplicatas.

# %%
Xref1 = (data.drop_duplicates(subset=['North(m)']))
Yref1 = (data.drop_duplicates(subset=['East(m)']))
Xref1 = list(Xref1['North(m)'])
Yref1 = list(Yref1['East(m)'])
Zlim = 10000 #profundidade limite em metros
nz = 100
Zref1 = np.linspace(0,Zlim,nz, endpoint=True)
#print(Xref1)
#X_bolinha = list(Xref1['North(m)'])

# %%
'''from random import sample 
# Prints list of random items of given length 
list1 = [1, 2, 3, 4, 5]  
  
print(sample(list1,3))'''
# Out:
# 'from random import sample \n# Prints list of random items of given length \nlist1 = [1, 2, 3, 4, 5]  \n  \nprint(sample(list1,3))'

# %%
#Caso com erro
#Vindo das duplicatas no uso do Choices
sorteados = [ ] 
numero_sorteios = 10
c = 0
while True:
    sorted_x, sorted_y = (random.choices(Xref), random.choices(Yref))
    if c == numero_sorteios:
        break
    if sorted_x and sorted_y not in sorteados:
        sorteados.append((sorted_x, sorted_y))
        c += 1

# %%
#Caso sem duplicadas
def sorted_coordinated (dicionario):
    Xref1 = dicionario.get('coodX')
    Yref1 = dicionario.get('coodY')
    Zref1 = dicionario.get('coodZ')
    numero_sorteios1 = dicionario.get('n')
#---------------------------------------------------------------------------------------------------------------------#
    sorteados1 = []
    c1 = 0 #contador
    while True:
        sorted_x1, sorted_y1,sorted_z1 = (random.choices(Xref1), random.choices(Yref1), random.choices(Zref1))
        if c1 == numero_sorteios1:
            break
        if sorted_x and sorted_y not in sorteados1:
            sorteados1.append((sorted_x1, sorted_y1,sorted_z1))
            c1 += 1
    return sorteados1

# %%
dic_bolinha = {'coodX': Xref1,
               'coodY': Yref1,
               'coodZ': Zref1,
               'n': 5}

resultadox= sorted_coordinated(dic_bolinha)
print(resultadox)
print(resultadox[3][1])
# Out:
# [([-4797.98], [4393.94], [4444.444444444444]), ([757.58], [-4393.94], [4848.484848484848]), ([757.58], [-4696.97], [6565.656565656565]), ([4898.99], [-1767.68], [4949.49494949495]), ([4797.98], [-555.56], [5252.525252525253])]
# [-1767.68]

# %%
'''
Sorteio das coordnedas x de n Bolinhas
    Etapa 0) Definir números de bolinhas
    Etapa 1) Localizar o min e max das coordenadas(X,y,z)
    Etapa 2) Procurar uma função np.random.uniform()
    Etapa 3) Utilizar a função random para gerar a coordenadas aleatórias(em função da etapa 0). Dicionário
    
'''
# Out:
# '\nSorteio das coordnedas x de n Bolinhas\n    Etapa 0) Definir números de bolinhas\n    Etapa 1) Localizar o min e max das coordenadas(X,y,z)\n    Etapa 2) Procurar uma função np.random.uniform()\n    Etapa 3) Utilizar a função random para gerar a coordenadas aleatórias(em função da etapa 0). Dicionário\n    \n'

# %%
xmax = data['North(m)'].max()
xmin = data['North(m)'].min()
ymin = data['East(m)'].min()
ymax = data['East(m)'].max()
zlim = 1000.0
z_min = 500.0
n = 4
cood_bounds = {'xmax': xmax,
                'xmin': xmin,
                'ymax': ymax,
                'ymin': ymin,
                'zlim': zlim,
                'z_min': z_min,
                'n': 4}

# %%
def sample_random_coordinated(dicionario):
    xmax = dicionario.get('xmax')
    xmin = dicionario.get('xmin')
    ymax = dicionario.get('ymax')
    ymin = dicionario.get('ymin')
    zlim = dicionario.get('zlim')
    zmin = dicionario.get('z_min')
    n = dicionario.get('n')
    
    resultadox=[]
    resultadoy=[]
    resultadoz=[]
#---------------------------------------------------------------------------------------------------------------------#
    for i in range(n):
        sorted_x1, sorted_y1,sorted_z1 = (np.random.uniform(xmin, xmax),
                                          np.random.uniform(ymin, ymax),
                                          np.random.uniform(z_min, zlim))
        resultadox.append(sorted_x1)
        resultadoy.append(sorted_y1)
        resultadoz.append(sorted_z1) 
#---------------------------------------------------------------------------------------------------------------------#        
    return resultadox, resultadoy, resultadoz

resultx, resulty, resultz = sample_random_coordinated(cood_bounds)
print(resultx)
#print(resultz)
#print(resulty)
# Out:
# [-2908.4598801127927, 1317.8463988954645, 4047.6855734744913, -3650.3524548711976]

# %%
fig = plt.figure(figsize=(10,10))
#ax = fig.gca(projection='3d')
plt.scatter(resulty, resultx, c=resultz, cmap='rainbow')
plt.xlabel('East(m)')
plt.xlim(-5000, 5000)
plt.ylim(-5000, 5000)
plt.ylabel('North(m)')
plt.colorbar()

plt.grid()

plt.show()

# %%
mag_bounds = {'inclmax': -30.0,
                'inclmin': -15.0,
                'declmax': 20.0,
                'declmin': 5.0,
                'mag_max': 15.0,
                'mag_min': 5.0,
                'n': 4}

# %%
def sample_random_mag(dicionario, homogeneo):
    inclmax = mag_bounds.get('inclmax')
    inclmin = mag_bounds.get('inclmin')
    declmax = mag_bounds.get('declmax')
    declmin = mag_bounds.get('declmin')
    magmax = mag_bounds.get('mag_max')
    magmin = mag_bounds.get('mag_min')
    n = mag_bounds.get('n')
#---------------------------------------------------------------------------------------------------------------------#
    resultadox=[]
    resultadoy=[]
    resultadoz=[]
#---------------------------------------------------------------------------------------------------------------------#
    if homogeneo == True:
        sorted_incl, sorted_decl, sorted_mag =(np.random.uniform(inclmax,inclmin),
                                   np.random.uniform(declmax, declmin),
                                   np.random.uniform(magmax, magmin))
#---------------------------------------------------------------------------------------------------------------------#
        for i in range(n):
            resultadox.append(sorted_incl)
            resultadoy.append(sorted_decl)
            resultadoz.append(sorted_mag)
#---------------------------------------------------------------------------------------------------------------------#
    else:
        for i in range(n):
            sorted_incl, sorted_decl, sorted_mag = (np.random.uniform(inclmax,inclmin),
                                                    np.random.uniform(declmax, declmin),
                                                    np.random.uniform(magmax, magmin))
            resultadox.append(sorted_incl)
            resultadoy.append(sorted_decl)
            resultadoz.append(sorted_mag)
    
    return resultadox, resultadoy, resultadoz

resultadox, resultadoy, resultadoz = sample_random_mag(mag_bounds, homogeneo = True)
print(resultadox)
# Out:
# [-24.66536338369667, -24.66536338369667, -24.66536338369667, -24.66536338369667]

# %%
print(resultadoy)
# Out:
# [10.348010452032508, 10.348010452032508, 10.348010452032508, 10.348010452032508]

# %%
print(resultadoz)
# Out:
# [11.694728643346076, 11.694728643346076, 11.694728643346076, 11.694728643346076]

# %% [markdown]
# # Cálculo de anomalia magnética de N bolinhas
#
# ### tfa5 =sphere.sphere_tfa(Xref,Yref,Zref,sphere5,Mi,I,D,inc,dec)

# %%
u = 5
e = [1, 2, 5, 4, 7]
k = 0
for i in range(u):
    o = e[i]
    k += o
    print(o)

print(k)
# Out:
# 1
# 2
# 5
# 4
# 7
# 19

# %%
# formatar a lista de entrada sphere = [x1,y1,z1,raio]
sphere1 = []
n = 4
for i in range(n):
    sphere1.append((resultx[i], resulty[i], resultz[i], raio))

# %%
print(raio)
print(sphere1)
print(sphere1[2])
# Out:
# 500.0
# [(-2908.4598801127927, -1978.739618933706, 686.1840200754275, 500.0), (1317.8463988954645, -3160.597528015403, 813.7872125955943, 500.0), (4047.6855734744913, 1846.0499707318031, 964.6070397835745, 500.0), (-3650.3524548711976, 953.4399632804771, 958.8845514926218, 500.0)]
# (4047.6855734744913, 1846.0499707318031, 964.6070397835745, 500.0)

# %%
#tfa5 =sphere.sphere_tfa(Xref,Yref,Zref,sphere5,Mi,I,D,inc,dec)

k = 0
for i in range(n):
    o = sphere.sphere_tfa(Xref,Yref,Zref,sphere1[i],resultadoz[i],I,D,resultadox[i],resultadoy[i])
    k += o

# %%
print(k)
print(type(k))
# Out:
# [[ 6.73431086  7.24058563  7.79388693 ... -9.42221952 -8.85746406
#   -8.33827288]
#  [ 6.37642567  6.87126235  7.41539007 ... -9.34212833 -8.77622588
#   -8.2569598 ]
#  [ 5.9501142   6.42532014  6.95128511 ... -9.21665629 -8.65423446
#   -8.13900524]
#  ...
#  [-1.67342043 -1.10708813 -0.48429529 ... 10.91177538  9.68353935
#    8.62413766]
#  [-1.4599572  -0.93452687 -0.36014239 ... 12.1584214  10.81391885
#    9.64956438]
#  [-1.28063231 -0.79387332 -0.26470704 ... 13.2822924  11.84141129
#   10.58857876]]
# <class 'numpy.ndarray'>

# %%
plt.close('all')
plt.figure(figsize=(13,10))
#******************************************************
plt.contourf(Yref, Xref, k, 20, cmap = plt.cm.RdBu_r,
             vmin= data['Total-Field Anomaly(nT)'].min(),
             vmax=data['Total-Field Anomaly(nT)'].max())
plt.title('Anomalia de Campo Total Calculado(nT)', fontsize = 12)
plt.xlabel('East (m)', fontsize = 10)
plt.ylabel('North (m)', fontsize = 10)
plt.colorbar()
plt.show()

# %%
def tfa_n_dots(dicionário1, dicionário2):
    incl = dicionario1.get('incl')
    decl = dicionario1.get('decl')
    mag = dicionario1.get('mag')
    n = dicionario1.get('n')
    
 #*****************************************************************************************   
    sphere1 = []
    n = 4
    for i in range(n):
        sphere1.append((resultx[i], resulty[i], resultz[i], raio))
#*****************************************************************************************     
    k = 0
    for i in range(n):
        o = sphere.sphere_tfa(Xref,Yref,Zref,sphere1[i],resultadoz[i],I,D,resultadox[i],resultadoy[i])
        k += o
    
    return tfa_n
