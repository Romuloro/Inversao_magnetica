# %%
import numpy as np
import random
import sys
import matplotlib.pyplot as plt
import pandas as pd
a = sys.path.append('../modules/') # endereco das funcoes implementadas por voce!
import plot_3D, auxiliars, salve_doc, sphere, sample_random, Operators

# %%
acquisition =  {'nx': 100,
                  'ny': 100,
                  'xmin': -10000,
                  'xmax': 10000,
                  'ymin': -10000,
                  'ymax': 10000,
                  'z': -100.0,
                  'color': '.r'}

cood_bounds = {'xmax': 250.0,
                'xmin': 40.0,
                'ymax': 100.0,
                'ymin': 0.0,
                'zlim': 150,
                'z_min': 100,
                'n': 5}

mag_bounds = {'inclmax': -20.0,
                'inclmin': 15.0,
                'declmax': 20.0,
                'declmin': -15.0,
                'magmax': 5.0,
                'magmin': 1.0,
                'homogeneo': True,
                'n': 5}

# %%
coodX, coodY, coodZ = sample_random.sample_random_coordinated(**cood_bounds)

incl, decl, mag = sample_random.sample_random_mag(**mag_bounds)

x, y, X, Y, Z = plot_3D.create_aquisicao(**acquisition)

# %%
balls_mag = {'incl': incl,
               'decl': decl,
               'mag': mag,
               'n': 5,
               'Xref': X,
               'Yref': Y,
               'Zref': Z,
               'I': 30.0,
               'D': 50.0,
               'coodX': coodX,
               'coodY': coodY,
               'coodZ': coodZ,
               'raio': 100.0}

tfa_n_bolinhas = sample_random.tfa_n_dots(**balls_mag)

plot_3D.modelo_anomalia_3D(Y, X, tfa_n_bolinhas, coodY, coodX, coodZ, mag)

# %%
population = {'xmax': 10000.0,
                'xmin': -10000.0,
                'ymax': 10000.0,
                'ymin': -10000.0,
                'zlim': 150.0,
                'z_min': 0.0,
                'n_dip': 7,
                'n_pop': 10,
                'inclmax': -80.0,
                'inclmin': 15.0,
                'declmax': 172.0,
                'declmin': -15.0,
                'magmax': 5.0,
                'magmin': 0.5,
                'homogeneo': True
                }

# %%
I, D = 30.0, 50.0

filhos_mut = {'xmax': 10000.0,
                'xmin': -10000.0,
                'ymax': 10000.0,
                'ymin': -10000.0,
                'zlim': 150.0,
                'z_min': 0.0,
                'n': 1,
                'inclmax': -80.0,
                'inclmin': 15.0,
                'declmax': 172.0,
                'declmin': -15.0,
                'magmax': 5.0,
                'magmin': 0.5,
                'homogeneo': True
                }

# %%
populacao = Operators.create_population(**population)
print("População Inicial: {}".format(populacao))
print("\n")

val_fit = []

for i in range(100):
    fit_ = Operators.fit_value(X, Y, Z, I, D, populacao, tfa_n_bolinhas)
    pais_ = Operators.tournament_selection(populacao, fit_)
    filho_ = Operators.crossover(pais_)
    filho_ = Operators.mutacao(filho_, **filhos_mut)
    populacao = Operators.elitismo(populacao, filho_, fit_)
    #fit_cont = Operators.fit_value(X, Y, Z, I, D, populacao, tfa_n_bolinhas)
    #min_fit = min(fit_cont)
    #val_fit.append(min_fit)

last_fit = Operators.fit_value(X, Y, Z, populacao, tfa_n_bolinhas)
# Out:
# População Inicial: [array([[-6.85100e+01, -7.40561e+03,  1.05940e+02, -2.08600e+01,
#          1.14040e+02,  2.48000e+00],
#        [-5.54713e+03,  6.06476e+03,  1.02350e+02, -2.08600e+01,
#          1.14040e+02,  2.48000e+00],
#        [-1.87641e+03,  1.18840e+02,  1.65200e+01, -2.08600e+01,
#          1.14040e+02,  2.48000e+00],
#        [ 4.47512e+03,  1.91234e+03,  2.69400e+01, -2.08600e+01,
#          1.14040e+02,  2.48000e+00],
#          1.68810e+02,  3.20000e+00]]), array([[-8.93500e+01,  3.82026e+03,  6.99000e+00, -1.46900e+01,
#         -1.06900e+01,  2.45000e+00],
#        [ 8.36369e+03,  4.76833e+03,  2.13000e+01, -1.46900e+01,
#         -1.06900e+01,  2.45000e+00],
#        [-1.93575e+03, -8.90174e+03,  1.68600e+01, -1.46900e+01,
#         -1.06900e+01,  2.45000e+00],
#        [-2.03084e+03,  8.66906e+03,  1.49910e+02, -1.46900e+01,
#         -1.06900e+01,  2.45000e+00],
#        [ 6.85624e+03, -8.43840e+03,  8.54800e+01, -1.46900e+01,
#         -1.06900e+01,  2.45000e+00],
#        [-1.21006e+03,  5.36537e+03,  5.73500e+01, -1.46900e+01,
#         -1.06900e+01,  2.45000e+00],
#        [ 6.20074e+03, -4.30263e+03,  9.80300e+01, -1.46900e+01,
#         -1.06900e+01,  2.45000e+00]]), array([[ 4.90214e+03,  4.41320e+02,  1.40110e+02, -5.76900e+01,
#          1.38000e+01,  3.97000e+00],
#        [ 4.52815e+03,  8.04931e+03,  3.80800e+01, -5.76900e+01,
#          1.38000e+01,  3.97000e+00],
#        [ 4.40300e+02, -4.62200e+03,  4.57000e+01, -5.76900e+01,
#          1.38000e+01,  3.97000e+00],
#        [-3.85012e+03,  2.04565e+03,  2.95500e+01, -5.76900e+01,
#          1.38000e+01,  3.97000e+00],
#        [ 1.18156e+03, -4.98854e+03,  1.35610e+02, -5.76900e+01,
#          1.38000e+01,  3.97000e+00],
#        [-8.20209e+03,  5.53414e+03,  8.40900e+01, -5.76900e+01,
#          1.38000e+01,  3.97000e+00],
#        [-7.78538e+03,  4.15778e+03,  7.80000e+01, -5.76900e+01,
#          1.38000e+01,  3.97000e+00]])]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-22111884475f> in <module>
#       6
#       7 for i in range(100):
# ----> 8     fit_ = Operators.fit_value(X, Y, Z, I, D, populacao, tfa_n_bolinhas)
#       9     pais_ = Operators.tournament_selection(populacao, fit_)
#      10     filho_ = Operators.crossover(pais_)
#
# C:\Rômulo\Mestrado\Inversao_magnetica\codes\modules\Operators.py in fit_value(X, Y, Z, I, D, pop, tfa_n_dip)
#      76             mag.append(pop[i][j][5])
#      77
# ---> 78         tfa_dip = sample_random.tfa_n_dots(incl, decl, mag, len(pop[0]), X, Y, Z, I, D, coodx, coody, coodz, raio)
#      79         fit = sample_random.f_difference(tfa_n_dip, tfa_dip)
#      80         fit_cada.append(float("{0:.2f}".format(fit)))
#
# C:\Rômulo\Mestrado\Inversao_magnetica\codes\modules\sample_random.py in tfa_n_dots(incl, decl, mag, n, Xref, Yref, Zref, I, D, coodX, coodY, coodZ, raio)
#     132     tfa_n = 0
#     133     for i in range(n):
# --> 134         tfa_cada = sphere.sphere_tfa(Xref,Yref,Zref,sphere1[i],mag[i],I,D,incl[i],decl[i])
#     135         tfa_n += tfa_cada
#     136
#
# C:\Rômulo\Mestrado\Inversao_magnetica\codes\modules\sphere.py in sphere_tfa(x, y, z, sphere, mag, incf, decf, incs, decs)
#     273     fx, fy, fz = aux.dircos(incf, decf)
#     274
# --> 275     if incs == None:
#     276         incs = incf
#     277     if decs == None:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
