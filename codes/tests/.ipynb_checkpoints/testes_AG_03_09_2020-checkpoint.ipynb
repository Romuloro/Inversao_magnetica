# %%
import numpy as np
import random
import sys
import matplotlib.pyplot as plt
import pandas as pd
a = sys.path.append('../modules/') # endereco das funcoes implementadas por voce!
import plot_3D, auxiliars, salve_doc, sphere, sample_random, Operators

# %%
acquisition =  {'nx': 100,
                  'ny': 100,
                  'xmin': -10000,
                  'xmax': 10000,
                  'ymin': -10000,
                  'ymax': 10000,
                  'z': -100.0,
                  'color': '.r'}

cood_bounds = {'xmax': 250.0,
                'xmin': 40.0,
                'ymax': 100.0,
                'ymin': 0.0,
                'zlim': 150,
                'z_min': 100,
                'n': 5}

mag_bounds = {'inclmax': -20.0,
                'inclmin': 15.0,
                'declmax': 20.0,
                'declmin': -15.0,
                'magmax': 5.0,
                'magmin': 1.0,
                'homogeneo': True,
                'n': 5}

# %%
coodX, coodY, coodZ = sample_random.sample_random_coordinated(**cood_bounds)

incl, decl, mag = sample_random.sample_random_mag(**mag_bounds)

x, y, X, Y, Z = plot_3D.create_aquisicao(**acquisition)

# %%
balls_mag = {'incl': incl,
               'decl': decl,
               'mag': mag,
               'n': 5,
               'Xref': X,
               'Yref': Y,
               'Zref': Z,
               'I': 30.0,
               'D': 50.0,
               'coodX': coodX,
               'coodY': coodY,
               'coodZ': coodZ,
               'raio': 100.0}

tfa_n_bolinhas = sample_random.tfa_n_dots(**balls_mag)

plot_3D.modelo_anomalia_3D(Y, X, tfa_n_bolinhas, coodY, coodX, coodZ, mag)

# %%
population = {'xmax': 10000.0,
                'xmin': -10000.0,
                'ymax': 10000.0,
                'ymin': -10000.0,
                'zlim': 150.0,
                'z_min': 0.0,
                'n_dip': 5,
                'n_pop': 10,
                'inclmax': -80.0,
                'inclmin': 15.0,
                'declmax': 172.0,
                'declmin': -150.0,
                'magmax': 5.0,
                'magmin': 0.5,
                'homogeneo': True
                }

# %%
I, D = 30.0, 50.0

filhos_mut = {'xmax': 10000.0,
                'xmin': -10000.0,
                'ymax': 10000.0,
                'ymin': -10000.0,
                'zlim': 150.0,
                'z_min': 0.0,
                'n': 1,
                'inclmax': -80.0,
                'inclmin': 15.0,
                'declmax': 172.0,
                'declmin': -15.0,
                'magmax': 5.0,
                'magmin': 0.5,
                'homogeneo': True
                }

# %%
'''populacao = Operators.create_population(**population)
print("População Inicial: {}".format(populacao))
print("\n")
print(populacao[0][0][5])

val_fit = []

for i in range(100):
    fit_ = Operators.fit_value(X, Y, Z, I, D, populacao, tfa_n_bolinhas)
    pais_ = Operators.tournament_selection(populacao, fit_)
    filho_ = Operators.crossover(pais_)
    filho_ = Operators.mutacao(filho_, **filhos_mut)
    populacao = Operators.elitismo(populacao, filho_, fit_)
    #fit_cont = Operators.fit_value(X, Y, Z, I, D, populacao, tfa_n_bolinhas)
    #min_fit = min(fit_cont)
    #val_fit.append(min_fit)

last_fit = Operators.fit_value(X, Y, Z, populacao, tfa_n_bolinhas)
'''
# Out:
# 'populacao = Operators.create_population(**population)\nprint("População Inicial: {}".format(populacao))\nprint("\n")\nprint(populacao[0][0][5])\n\nval_fit = []\n\nfor i in range(100):\n    fit_ = Operators.fit_value(X, Y, Z, I, D, populacao, tfa_n_bolinhas)\n    pais_ = Operators.tournament_selection(populacao, fit_)\n    filho_ = Operators.crossover(pais_)\n    filho_ = Operators.mutacao(filho_, **filhos_mut)\n    populacao = Operators.elitismo(populacao, filho_, fit_)\n    #fit_cont = Operators.fit_value(X, Y, Z, I, D, populacao, tfa_n_bolinhas)\n    #min_fit = min(fit_cont)\n    #val_fit.append(min_fit)\n\nlast_fit = Operators.fit_value(X, Y, Z, populacao, tfa_n_bolinhas)\n'

# %%
pop = Operators.create_population(**population)

# %%
coodX = []
coodY = []
coodZ = []
incl = []
decl = []
mag = []

for i in range(len(pop)):
    coodx1 = []
    coodX.append(coodx1)
    coody1 = []
    coodY.append(coody1)
    coodz1 = []
    coodZ.append(coodz1)
    incl1 = []
    incl.append(incl1)
    decl1 = []
    decl.append(decl1)
    mag1 = []
    mag.append(mag1)
    for j in range(len(pop[0])):
        coodx1.append(pop[i][j][0])
        coody1.append(pop[i][j][1])
        coodz1.append(pop[i][j][2])
        incl1.append(pop[i][j][3])
        decl1.append(pop[i][j][4])
        mag1.append(pop[i][j][5])

# %%
view = [190, 130]
fig = plt.figure(figsize=(15, 15))
ax = fig.gca(projection='3d')
#plano = ax.contourf(Yref, Xref, tfa_n_bolinhas, offset=0, cmap=plt.cm.RdBu_r)
individuo0 = ax.scatter(coodX[0], coodY[0], coodZ[0], c=coodZ[0], depthshade=True, cmap='jet', marker='^', s = 200.0, label = 'Individuo 0')
individuo1 = ax.scatter(coodX[1], coodY[1], coodZ[1], c=coodZ[1], depthshade=True, cmap='jet', marker='o', s = 200.0, label = 'Individuo 1')
individuo2 = ax.scatter(coodX[2], coodY[2], coodZ[2], c=coodZ[2], depthshade=True, cmap='jet', marker='*', s = 200.0, label = 'Individuo 2')
individuo3 = ax.scatter(coodX[3], coodY[3], coodZ[3], c=coodZ[3], depthshade=True, cmap='jet', marker='X', s = 200.0, label = 'Individuo 3')
individuo4 = ax.scatter(coodX[4], coodY[4], coodZ[4], c=coodZ[4], depthshade=True, cmap='jet', marker='s', s = 200.0, label = 'Individuo 4')
individuo5 = ax.scatter(coodX[5], coodY[5], coodZ[5], c=coodZ[5], depthshade=True, cmap='jet', marker='D', s = 200.0, label = 'Individuo 5')
individuo6 = ax.scatter(coodX[6], coodY[6], coodZ[6], c=coodZ[6], depthshade=True, cmap='jet', marker='p', s = 200.0, label = 'Individuo 6')
individuo7 = ax.scatter(coodX[7], coodY[7], coodZ[7], c=coodZ[7], depthshade=True, cmap='jet', marker='P', s = 200.0, label = 'Individuo 7')
individuo8 = ax.scatter(coodX[8], coodY[8], coodZ[8], c=coodZ[8], depthshade=True, cmap='jet', marker='1', s = 200.0, label = 'Individuo 8')
individuo9 = ax.scatter(coodX[9], coodY[9], coodZ[9], c=coodZ[9], depthshade=True, cmap='jet', marker='+', s = 200.0, label = 'Individuo 9')

#plt.xlim(-5000, 5000)
#plt.ylim(-5000, 5000)
ax.set_xlabel('East (m)', fontsize=20)
ax.set_ylabel('North (m)', fontsize=20)
ax.set_zlabel('Depth (m)', fontsize=20)
plt.colorbar(individuo0, shrink=0.65)
ax.legend()
plt.grid()
ax.view_init(view[0], view[1])
plt.show()
