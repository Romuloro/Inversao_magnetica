# %%
import warnings

import numpy as np

warnings.filterwarnings("ignore")
import sys
a = sys.path.append('../modules/')
c = sys.path.append('../tests/')
import os
import pandas as pd

import random

import matplotlib.pyplot as plt


from datetime import datetime
import plot_3D, auxiliars, salve_doc, sphere, sample_random, Operators

from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection

# %%
import genetic_algorithm as ga

# %%
populacao, anomaly_better, ind_better, val_fit, val_phi, val_theta, incl_better, decl_better, diversity_x, diversity_y, diversity_z, diversity_incl, diversity_decl, diversity_mom = ga.ga(ga.lamb, ga.n, ga.anomaly_cubo, ga.filhos_mut, ga.population)

# %%
n_diversity_x = len(diversity_x)
n_diversity_y = len(diversity_y)
n_diversity_z = len(diversity_z)
n_diversity_incl = len(diversity_incl)
n_diversity_decl = len(diversity_decl)
n_diversity_mom = len(diversity_mom)

# %%
x = np.linspace(0, n_diversity_x, n_diversity_x)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, diversity_x)
plt.ylim(0, 2000)
plt.title('N - Ranked', fontsize=20)
plt.xlabel('Generations', fontsize=20)
plt.ylabel('Std Cood X(q)', fontsize=20)
plt.grid()
plt.show()

# %%
x = np.linspace(0, n_diversity_y, n_diversity_y)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, diversity_y)
plt.ylim(0, 2200)
plt.title('N - Ranked', fontsize=20)
plt.xlabel('Generations', fontsize=20)
plt.ylabel('Std Cood Y(q)', fontsize=20)
plt.grid()
plt.show()

# %%
x = np.linspace(0, n_diversity_z, n_diversity_z)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, diversity_z)
plt.ylim(0, 2000)
plt.title('N - Ranked', fontsize=20)
plt.xlabel('Generations', fontsize=20)
plt.ylabel('Std Cood Z(q)', fontsize=20)
plt.grid()
plt.show()

# %%
x = np.linspace(0, n_diversity_incl, n_diversity_incl)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, diversity_incl)
#plt.ylim(0, 2000)
plt.title('N - Ranked', fontsize=20)
plt.xlabel('Generations', fontsize=20)
plt.ylabel('Std inclination(q)', fontsize=20)
plt.grid()
plt.show()

# %%
x = np.linspace(0, n_diversity_decl, n_diversity_decl)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, diversity_decl)
#plt.ylim(0, 2000)
plt.title('N - Ranked', fontsize=20)
plt.xlabel('Generations', fontsize=20)
plt.ylabel('Std declination(q)', fontsize=20)
plt.grid()
plt.show()

# %%
x = np.linspace(0, n_diversity_mom, n_diversity_mom)
fig = plt.figure(figsize=(8, 8))
plt.plot(x, diversity_mom)
#plt.ylim(0, 2000)
plt.title('N - Ranked', fontsize=20)
plt.xlabel('Generations', fontsize=20)
plt.ylabel('Std momento magnético(q)', fontsize=20)
plt.grid()
plt.show()
